# %% [markdown]
# # Artificial Intelligence Nanodegree
#
# ## Convolutional Neural Networks
#
# ## Project: Write an Algorithm for a Dog Identification App
#
# ---
#
# In this notebook, some template code has already been provided for you, and you will need to implement additional functionality to successfully complete this project. You will not need to modify the included code beyond what is requested. Sections that begin with **'(IMPLEMENTATION)'** in the header indicate that the following block of code will require additional functionality which you must provide. Instructions will be provided for each section, and the specifics of the implementation are marked in the code block with a 'TODO' statement. Please be sure to read the instructions carefully!
#
# > **Note**: Once you have completed all of the code implementations, you need to finalize your work by exporting the iPython Notebook as an HTML document. Before exporting the notebook to html, all of the code cells need to have been run so that reviewers can see the final implementation and output. You can then export the notebook by using the menu above and navigating to  \n",
#     "**File -> Download as -> HTML (.html)**. Include the finished document along with this notebook as your submission.
#
# In addition to implementing code, there will be questions that you must answer which relate to the project and your implementation. Each section where you will answer a question is preceded by a **'Question X'** header. Carefully read each question and provide thorough answers in the following text boxes that begin with **'Answer:'**. Your project submission will be evaluated based on your answers to each of the questions and the implementation you provide.
#
# >**Note:** Code and Markdown cells can be executed using the **Shift + Enter** keyboard shortcut.  Markdown cells can be edited by double-clicking the cell to enter edit mode.
#
# The rubric contains _optional_ "Stand Out Suggestions" for enhancing the project beyond the minimum requirements. If you decide to pursue the "Stand Out Suggestions", you should include the code in this IPython notebook.
#
#
#
# ---
# ### Why We're Here
#
# In this notebook, you will make the first steps towards developing an algorithm that could be used as part of a mobile or web app.  At the end of this project, your code will accept any user-supplied image as input.  If a dog is detected in the image, it will provide an estimate of the dog's breed.  If a human is detected, it will provide an estimate of the dog breed that is most resembling.  The image below displays potential sample output of your finished project (... but we expect that each student's algorithm will behave differently!).
#
# ![Sample Dog Output](images/sample_dog_output.png)
#
# In this real-world setting, you will need to piece together a series of models to perform different tasks; for instance, the algorithm that detects humans in an image will be different from the CNN that infers dog breed.  There are many points of possible failure, and no perfect algorithm exists.  Your imperfect solution will nonetheless create a fun user experience!
#
# ### The Road Ahead
#
# We break the notebook into separate steps.  Feel free to use the links below to navigate the notebook.
#
# * [Step 0](#step0): Import Datasets
# * [Step 1](#step1): Detect Humans
# * [Step 2](#step2): Detect Dogs
# * [Step 3](#step3): Create a CNN to Classify Dog Breeds (from Scratch)
# * [Step 4](#step4): Use a CNN to Classify Dog Breeds (using Transfer Learning)
# * [Step 5](#step5): Create a CNN to Classify Dog Breeds (using Transfer Learning)
# * [Step 6](#step6): Write your Algorithm
# * [Step 7](#step7): Test Your Algorithm
#
# ---
# <a id='step0'></a>
# ## Step 0: Import Datasets
#
# ### Import Dog Dataset
#
# In the code cell below, we import a dataset of dog images.  We populate a few variables through the use of the `load_files` function from the scikit-learn library:
# - `train_files`, `valid_files`, `test_files` - numpy arrays containing file paths to images
# - `train_targets`, `valid_targets`, `test_targets` - numpy arrays containing onehot-encoded classification labels
# - `dog_names` - list of string-valued dog breed names for translating labels

# %%
from sklearn.datasets import load_files       
from keras.utils import np_utils
import numpy as np
from glob import glob

# define function to load train, test, and validation datasets
def load_dataset(path):
    data = load_files(path)
    dog_files = np.array(data['filenames'])
    dog_targets = np_utils.to_categorical(np.array(data['target']), 133)
    return dog_files, dog_targets

# load train, test, and validation datasets
train_files, train_targets = load_dataset('dogImages/train')
valid_files, valid_targets = load_dataset('dogImages/valid')
test_files, test_targets = load_dataset('dogImages/test')

# load list of dog names
dog_names = [item[20:-1] for item in sorted(glob("dogImages/train/*/"))]

# print statistics about the dataset
print('There are %d total dog categories.' % len(dog_names))
print('There are %s total dog images.\n' % len(np.hstack([train_files, valid_files, test_files])))
print('There are %d training dog images.' % len(train_files))
print('There are %d validation dog images.' % len(valid_files))
print('There are %d test dog images.'% len(test_files))
# Out:
# There are 133 total dog categories.
# There are 8351 total dog images.
#
# There are 6680 training dog images.
# There are 835 validation dog images.
# There are 836 test dog images.

# %% [markdown]
# ### Import Human Dataset
#
# In the code cell below, we import a dataset of human images, where the file paths are stored in the numpy array `human_files`.

# %%
import random
random.seed(8675309)

# load filenames in shuffled human dataset
human_files = np.array(glob("lfw/*/*"))
random.shuffle(human_files)

# print statistics about the dataset
print('There are %d total human images.' % len(human_files))
# Out:
# There are 13233 total human images.

# %% [markdown]
# ---
# <a id='step1'></a>
# ## Step 1: Detect Humans
#
# We use OpenCV's implementation of [Haar feature-based cascade classifiers](http://docs.opencv.org/trunk/d7/d8b/tutorial_py_face_detection.html) to detect human faces in images.  OpenCV provides many pre-trained face detectors, stored as XML files on [github](https://github.com/opencv/opencv/tree/master/data/haarcascades).  We have downloaded one of these detectors and stored it in the `haarcascades` directory.
#
# In the next code cell, we demonstrate how to use this detector to find human faces in a sample image.

# %%
import cv2                
import matplotlib.pyplot as plt                        
# %matplotlib inline                               

# extract pre-trained face detector
face_cascade = cv2.CascadeClassifier('haarcascades/haarcascade_frontalface_alt.xml')

# load color (BGR) image
img = cv2.imread(human_files[3])
# convert BGR image to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# find faces in image
faces = face_cascade.detectMultiScale(gray)

# print number of faces detected in the image
print('Number of faces detected:', len(faces))

# get bounding box for each detected face
for (x,y,w,h) in faces:
    # add bounding box to color image
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    
# convert BGR image to RGB for plotting
cv_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# display the image, along with bounding box
plt.imshow(cv_rgb)
plt.show()
# Out:
# Number of faces detected: 1

# %% [markdown]
# Before using any of the face detectors, it is standard procedure to convert the images to grayscale.  The `detectMultiScale` function executes the classifier stored in `face_cascade` and takes the grayscale image as a parameter.
#
# In the above code, `faces` is a numpy array of detected faces, where each row corresponds to a detected face.  Each detected face is a 1D array with four entries that specifies the bounding box of the detected face.  The first two entries in the array (extracted in the above code as `x` and `y`) specify the horizontal and vertical positions of the top left corner of the bounding box.  The last two entries in the array (extracted here as `w` and `h`) specify the width and height of the box.
#
# ### Write a Human Face Detector
#
# We can use this procedure to write a function that returns `True` if a human face is detected in an image and `False` otherwise.  This function, aptly named `face_detector`, takes a string-valued file path to an image as input and appears in the code block below.

# %%
# returns "True" if face is detected in image stored at img_path
def face_detector(img_path):
    img = cv2.imread(img_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray)
    return len(faces) > 0

# %% [markdown]
# ### (IMPLEMENTATION) Assess the Human Face Detector
#
# __Question 1:__ Use the code cell below to test the performance of the `face_detector` function.
# - What percentage of the first 100 images in `human_files` have a detected human face?
# - What percentage of the first 100 images in `dog_files` have a detected human face?
#
# Ideally, we would like 100% of human images with a detected face and 0% of dog images with a detected face.  You will see that our algorithm falls short of this goal, but still gives acceptable performance.  We extract the file paths for the first 100 images from each of the datasets and store them in the numpy arrays `human_files_short` and `dog_files_short`.
#
# __Answer:__

# %%
human_files_short = human_files[:100]
dog_files_short = train_files[:100]
# Do NOT modify the code above this line.

## TODO: Test the performance of the face_detector algorithm 
## on the images in human_files_short and dog_files_short.
human_image=0
dog_image=0
human_image =len([image for image in human_files_short if face_detector(image)])
dog_image=len([image for image in dog_files_short if face_detector(image)])

print(str(human_image)+"%")
print(str(dog_image)+"%")
# Out:
# 99%
# 11%

# %% [markdown]
# __Question 2:__ This algorithmic choice necessitates that we communicate to the user that we accept human images only when they provide a clear view of a face (otherwise, we risk having unneccessarily frustrated users!). In your opinion, is this a reasonable expectation to pose on the user? If not, can you think of a way to detect humans in images that does not necessitate an image with a clearly presented face?
#
# __Answer:__
# Of course is a bad way to detect human photo or any another photo like put condition to return the result. One of the ways to do that by learning neural network to detect the human face pattern (Face perception) the nose, mouth, eyes, and ears. So, when the neural return value for the human face is detected.
#
# We suggest the face detector from OpenCV as a potential way to detect human images in your algorithm, but you are free to explore other approaches, especially approaches that make use of deep learning :).  Please use the code cell below to design and test your own face detection algorithm.  If you decide to pursue this _optional_ task, report performance on each of the datasets.

# %%
## (Optional) TODO: Report the performance of another  
## face detection algorithm on the LFW dataset
### Feel free to use as many code cells as needed.

# %% [markdown]
# ---
# <a id='step2'></a>
# ## Step 2: Detect Dogs
#
# In this section, we use a pre-trained [ResNet-50](http://ethereon.github.io/netscope/#/gist/db945b393d40bfa26006) model to detect dogs in images.  Our first line of code downloads the ResNet-50 model, along with weights that have been trained on [ImageNet](http://www.image-net.org/), a very large, very popular dataset used for image classification and other vision tasks.  ImageNet contains over 10 million URLs, each linking to an image containing an object from one of [1000 categories](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a).  Given an image, this pre-trained ResNet-50 model returns a prediction (derived from the available categories in ImageNet) for the object that is contained in the image.

# %%
from keras.applications.resnet50 import ResNet50

# define ResNet50 model
ResNet50_model = ResNet50(weights='imagenet')

# %% [markdown]
# ### Pre-process the Data
#
# When using TensorFlow as backend, Keras CNNs require a 4D array (which we'll also refer to as a 4D tensor) as input, with shape
#
# $$
# (\text{nb_samples}, \text{rows}, \text{columns}, \text{channels}),
# $$
#
# where `nb_samples` corresponds to the total number of images (or samples), and `rows`, `columns`, and `channels` correspond to the number of rows, columns, and channels for each image, respectively.
#
# The `path_to_tensor` function below takes a string-valued file path to a color image as input and returns a 4D tensor suitable for supplying to a Keras CNN.  The function first loads the image and resizes it to a square image that is $224 \times 224$ pixels.  Next, the image is converted to an array, which is then resized to a 4D tensor.  In this case, since we are working with color images, each image has three channels.  Likewise, since we are processing a single image (or sample), the returned tensor will always have shape
#
# $$
# (1, 224, 224, 3).
# $$
#
# The `paths_to_tensor` function takes a numpy array of string-valued image paths as input and returns a 4D tensor with shape
#
# $$
# (\text{nb_samples}, 224, 224, 3).
# $$
#
# Here, `nb_samples` is the number of samples, or number of images, in the supplied array of image paths.  It is best to think of `nb_samples` as the number of 3D tensors (where each 3D tensor corresponds to a different image) in your dataset!

# %%
from keras.preprocessing import image                  
from tqdm import tqdm

def path_to_tensor(img_path):
    # loads RGB image as PIL.Image.Image type
    img = image.load_img(img_path, target_size=(224, 224))
    # convert PIL.Image.Image type to 3D tensor with shape (224, 224, 3)
    x = image.img_to_array(img)
    # convert 3D tensor to 4D tensor with shape (1, 224, 224, 3) and return 4D tensor
    return np.expand_dims(x, axis=0)

def paths_to_tensor(img_paths):
    print(img_paths)
    list_of_tensors = [path_to_tensor(img_path) for img_path in tqdm(img_paths)]
    return np.vstack(list_of_tensors)

# %% [markdown]
# ### Making Predictions with ResNet-50
#
# Getting the 4D tensor ready for ResNet-50, and for any other pre-trained model in Keras, requires some additional processing.  First, the RGB image is converted to BGR by reordering the channels.  All pre-trained models have the additional normalization step that the mean pixel (expressed in RGB as $[103.939, 116.779, 123.68]$ and calculated from all pixels in all images in ImageNet) must be subtracted from every pixel in each image.  This is implemented in the imported function `preprocess_input`.  If you're curious, you can check the code for `preprocess_input` [here](https://github.com/fchollet/keras/blob/master/keras/applications/imagenet_utils.py).
#
# Now that we have a way to format our image for supplying to ResNet-50, we are now ready to use the model to extract the predictions.  This is accomplished with the `predict` method, which returns an array whose $i$-th entry is the model's predicted probability that the image belongs to the $i$-th ImageNet category.  This is implemented in the `ResNet50_predict_labels` function below.
#
# By taking the argmax of the predicted probability vector, we obtain an integer corresponding to the model's predicted object class, which we can identify with an object category through the use of this [dictionary](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a).

# %%
from keras.applications.resnet50 import preprocess_input, decode_predictions

def ResNet50_predict_labels(img_path):
    # returns prediction vector for image located at img_path
    img = preprocess_input(path_to_tensor(img_path))
    return np.argmax(ResNet50_model.predict(img))

# %% [markdown]
# ### Write a Dog Detector
#
# While looking at the [dictionary](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a), you will notice that the categories corresponding to dogs appear in an uninterrupted sequence and correspond to dictionary keys 151-268, inclusive, to include all categories from `'Chihuahua'` to `'Mexican hairless'`.  Thus, in order to check to see if an image is predicted to contain a dog by the pre-trained ResNet-50 model, we need only check if the `ResNet50_predict_labels` function above returns a value between 151 and 268 (inclusive).
#
# We use these ideas to complete the `dog_detector` function below, which returns `True` if a dog is detected in an image (and `False` if not).

# %%
### returns "True" if a dog is detected in the image stored at img_path
def dog_detector(img_path):
    prediction = ResNet50_predict_labels(img_path)
    return ((prediction <= 268) & (prediction >= 151))

# %% [markdown]
# ### (IMPLEMENTATION) Assess the Dog Detector
#
# __Question 3:__ Use the code cell below to test the performance of your `dog_detector` function.
# - What percentage of the images in `human_files_short` have a detected dog?
# - What percentage of the images in `dog_files_short` have a detected dog?
#
# __Answer:__

# %%
### TODO: Test the performance of the dog_detector function
### on the images in human_files_short and dog_files_short.

human_image_RestNet50 =len([ image for image in human_files_short if dog_detector(image)])
dog_image_RestNet50=len([image for image in dog_files_short if dog_detector(image)])

print(str(human_image_RestNet50)+"%")
print(str(dog_image_RestNet50)+"%")
# Out:
# 1%
# 100%

# %% [markdown]
# ---
# <a id='step3'></a>
# ## Step 3: Create a CNN to Classify Dog Breeds (from Scratch)
#
# Now that we have functions for detecting humans and dogs in images, we need a way to predict breed from images.  In this step, you will create a CNN that classifies dog breeds.  You must create your CNN _from scratch_ (so, you can't use transfer learning _yet_!), and you must attain a test accuracy of at least 1%.  In Step 5 of this notebook, you will have the opportunity to use transfer learning to create a CNN that attains greatly improved accuracy.
#
# Be careful with adding too many trainable layers!  More parameters means longer training, which means you are more likely to need a GPU to accelerate the training process.  Thankfully, Keras provides a handy estimate of the time that each epoch is likely to take; you can extrapolate this estimate to figure out how long it will take for your algorithm to train.
#
# We mention that the task of assigning breed to dogs from images is considered exceptionally challenging.  To see why, consider that *even a human* would have great difficulty in distinguishing between a Brittany and a Welsh Springer Spaniel.
#
# Brittany | Welsh Springer Spaniel
# - | -
# <img src="images/Brittany_02625.jpg" width="100"> | <img src="images/Welsh_springer_spaniel_08203.jpg" width="200">
#
# It is not difficult to find other dog breed pairs with minimal inter-class variation (for instance, Curly-Coated Retrievers and American Water Spaniels).
#
# Curly-Coated Retriever | American Water Spaniel
# - | -
# <img src="images/Curly-coated_retriever_03896.jpg" width="200"> | <img src="images/American_water_spaniel_00648.jpg" width="200">
#
#
# Likewise, recall that labradors come in yellow, chocolate, and black.  Your vision-based algorithm will have to conquer this high intra-class variation to determine how to classify all of these different shades as the same breed.
#
# Yellow Labrador | Chocolate Labrador | Black Labrador
# - | -
# <img src="images/Labrador_retriever_06457.jpg" width="150"> | <img src="images/Labrador_retriever_06455.jpg" width="240"> | <img src="images/Labrador_retriever_06449.jpg" width="220">
#
# We also mention that random chance presents an exceptionally low bar: setting aside the fact that the classes are slightly imabalanced, a random guess will provide a correct answer roughly 1 in 133 times, which corresponds to an accuracy of less than 1%.
#
# Remember that the practice is far ahead of the theory in deep learning.  Experiment with many different architectures, and trust your intuition.  And, of course, have fun!
#
# ### Pre-process the Data
#
# We rescale the images by dividing every pixel in every image by 255.

# %%
from PIL import ImageFile                            
ImageFile.LOAD_TRUNCATED_IMAGES = True                 

# pre-process the data for Keras
train_tensors = paths_to_tensor(train_files).astype('float32')/255
valid_tensors = paths_to_tensor(valid_files).astype('float32')/255
test_tensors = paths_to_tensor(test_files).astype('float32')/255
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 6680/6680 [01:27<00:00, 76.30it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 835/835 [00:09<00:00, 87.04it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 836/836 [00:09<00:00, 125.12it/s]

# %% [markdown]
# ### (IMPLEMENTATION) Model Architecture
#
# Create a CNN to classify dog breed.  At the end of your code cell block, summarize the layers of your model by executing the line:
#
#         model.summary()
#
# We have imported some Python modules to get you started, but feel free to import as many modules as you need.  If you end up getting stuck, here's a hint that specifies a model that trains relatively fast on CPU and attains >1% test accuracy in 5 epochs:
#
# ![Sample CNN](images/sample_cnn.png)
#
# __Question 4:__ Outline the steps you took to get to your final CNN architecture and your reasoning at each step.  If you chose to use the hinted architecture above, describe why you think that CNN architecture should work well for the image classification task.
#
# __Answer:__

# %% [markdown]
# In this CNN layer there are 3 Convolutional layers, 2 MaxPooling2D layers, and before the Dense layer, there is GlobalAveragePooling2D which is the main idea of it is to convert the 2d array of the photos to one dimension array by getting the average of the over all value for each filter. the Dense layer has 133 output because we have 133 different Dog breed and hight probability go to the right breed.

# %%
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.layers import Dropout, Flatten, Dense,Activation
from keras.models import Sequential

model = Sequential()

### TODO: Define your architecture.
model.add(Conv2D(filters=16, kernel_size=5, strides=1,padding='valid',activation='relu',input_shape=train_tensors[0].shape))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(filters=32, kernel_size=5, strides=1,padding='valid',activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(filters=64, kernel_size=5, strides=1,padding='valid',activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(GlobalAveragePooling2D())
model.add(Dense(133, activation='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 220, 220, 16)      1216
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 110, 110, 16)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 106, 106, 32)      12832
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 53, 53, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 49, 49, 64)        51264
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 24, 24, 64)        0
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 133)               8645
# =================================================================
# Total params: 73,957
# Trainable params: 73,957
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Compile the Model

# %%
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### (IMPLEMENTATION) Train the Model
#
# Train your model in the code cell below.  Use model checkpointing to save the model that attains the best validation loss.
#
# You are welcome to [augment the training data](https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html), but this is not a requirement.

# %%
    from keras.callbacks import ModelCheckpoint  
    from keras.preprocessing.image import ImageDataGenerator

    ### TODO: specify the number of epochs that you would like to use to train the model.
    datagenerator_train=ImageDataGenerator(width_shift_range=0.1,height_shift_range=0.1,horizontal_flip=True)
    datagenerator_validate=ImageDataGenerator(width_shift_range=0.1,height_shift_range=0.1,horizontal_flip=True)

    datagenerator_train.fit(train_tensors)
    datagenerator_validate.fit(valid_tensors)

    batch_size = 20
    epochs = 50
    ### Do NOT modify the code below this line.

    checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.from_scratch.hdf5', 
                                   verbose=1, save_best_only=True)

    model.fit_generator(datagenerator_train.flow(train_tensors,train_targets,batch_size=batch_size),
                        steps_per_epoch=train_tensors.shape[0] // batch_size,
                        epochs=epochs, verbose=1, callbacks=[checkpointer],
                        validation_data=datagenerator_validate.flow(valid_tensors, valid_targets, batch_size=batch_size),
                        validation_steps=valid_tensors.shape[0] // batch_size)
#fit the model without Augmentation
# model.fit(train_tensors[:int((len(train_tensors)*rate)/100)], train_targets[:int((len(train_targets)*rate)/100)], 
#           validation_data=(valid_tensors[:int((len(valid_tensors)*rate)/100)], valid_targets[:int((len(valid_targets)*rate)/100)]),
#           epochs=epochs, batch_size=20, callbacks=[checkpointer], verbose=1)
# Out:
# Epoch 1/50
# 333/334 [============================>.] - ETA: 0s - loss: 4.8864 - acc: 0.0075Epoch 00000: val_loss improved from inf to 4.85835, saving model to saved_models/weights.best.from_scratch.hdf5
# 334/334 [==============================] - 62s - loss: 4.8864 - acc: 0.0075 - val_loss: 4.8583 - val_acc: 0.0098
# Epoch 2/50
# 333/334 [============================>.] - ETA: 0s - loss: 4.8395 - acc: 0.0149Epoch 00001: val_loss improved from 4.85835 to 4.80926, saving model to saved_models/weights.best.from_scratch.hdf5
# 334/334 [==============================] - 61s - loss: 4.8399 - acc: 0.0148 - val_loss: 4.8093 - val_acc: 0.0183
# Epoch 3/50
# 333/334 [============================>.] - ETA: 0s - loss: 4.7612 - acc: 0.0209Epoch 00002: val_loss improved from 4.80926 to 4.73783, saving model to saved_models/weights.best.from_scratch.hdf5
# 334/334 [==============================] - 61s - loss: 4.7609 - acc: 0.0210 - val_loss: 4.7378 - val_acc: 0.0207
# Epoch 4/50
# 333/334 [============================>.] - ETA: 0s - loss: 4.7196 - acc: 0.0231Epoch 00003: val_loss improved from 4.73783 to 4.71132, saving model to saved_models/weights.best.from_scratch.hdf5
# 334/334 [==============================] - 60s - loss: 4.7200 - acc: 0.0231 - val_loss: 4.7113 - val_acc: 0.0293
# Epoch 5/50
# 333/334 [============================>.] - ETA: 0s - loss: 4.6724 - acc: 0.0293Epoch 00004: val_loss improved from 4.71132 to 4.62910, saving model to saved_models/weights.best.from_scratch.hdf5
# 334/334 [==============================] - 61s - loss: 4.6720 - acc: 0.0292 - val_loss: 4.6291 - val_acc: 0.0317
# Epoch 6/50
# 333/334 [============================>.] - ETA: 0s - loss: 4.5888 - acc: 0.0350Epoch 00005: val_loss did not improve
# 334/334 [==============================] - 60s - loss: 4.5883 - acc: 0.0355 - val_loss: 4.6441 - val_acc: 0.0415
# Epoch 7/50
# 333/334 [============================>.] - ETA: 0s - loss: 4.5118 - acc: 0.0474Epoch 00006: val_loss improved from 4.62910 to 4.48330, saving model to saved_models/weights.best.from_scratch.hdf5
# 334/334 [==============================] - 60s - loss: 4.5110 - acc: 0.0475 - val_loss: 4.4833 - val_acc: 0.0512
# Epoch 8/50
# 333/334 [============================>.] - ETA: 0s - loss: 4.4243 - acc: 0.0514Epoch 00007: val_loss improved from 4.48330 to 4.45416, saving model to saved_models/weights.best.from_scratch.hdf5
# 334/334 [==============================] - 61s - loss: 4.4246 - acc: 0.0513 - val_loss: 4.4542 - val_acc: 0.0463
# Epoch 9/50
# 333/334 [============================>.] - ETA: 0s - loss: 4.3614 - acc: 0.0560Epoch 00008: val_loss improved from 4.45416 to 4.43721, saving model to saved_models/weights.best.from_scratch.hdf5
# 334/334 [==============================] - 61s - loss: 4.3626 - acc: 0.0561 - val_loss: 4.4372 - val_acc: 0.0439
# Epoch 10/50
# 333/334 [============================>.] - ETA: 0s - loss: 4.2969 - acc: 0.0641Epoch 00009: val_loss improved from 4.43721 to 4.37999, saving model to saved_models/weights.best.from_scratch.hdf5
# 334/334 [==============================] - 60s - loss: 4.2968 - acc: 0.0642 - val_loss: 4.3800 - val_acc: 0.0634
# Epoch 11/50
# 333/334 [============================>.] - ETA: 0s - loss: 4.2345 - acc: 0.0713Epoch 00010: val_loss improved from 4.37999 to 4.34810, saving model to saved_models/weights.best.from_scratch.hdf5
# 334/334 [==============================] - 60s - loss: 4.2342 - acc: 0.0711 - val_loss: 4.3481 - val_acc: 0.0573
# Epoch 12/50
# 333/334 [============================>.] - ETA: 0s - loss: 4.1845 - acc: 0.0743Epoch 00011: val_loss improved from 4.34810 to 4.28181, saving model to saved_models/weights.best.from_scratch.hdf5
# 334/334 [==============================] - 60s - loss: 4.1841 - acc: 0.0744 - val_loss: 4.2818 - val_acc: 0.0622
# Epoch 13/50
# 333/334 [============================>.] - ETA: 0s - loss: 4.1339 - acc: 0.0847Epoch 00012: val_loss improved from 4.28181 to 4.22288, saving model to saved_models/weights.best.from_scratch.hdf5
# 334/334 [==============================] - 61s - loss: 4.1342 - acc: 0.0847 - val_loss: 4.2229 - val_acc: 0.0768
# Epoch 14/50
# 333/334 [============================>.] - ETA: 0s - loss: 4.0844 - acc: 0.0874Epoch 00013: val_loss did not improve
# 334/334 [==============================] - 61s - loss: 4.0831 - acc: 0.0876 - val_loss: 4.2285 - val_acc: 0.0707
# Epoch 15/50
# 333/334 [============================>.] - ETA: 0s - loss: 4.0133 - acc: 0.0977Epoch 00014: val_loss improved from 4.22288 to 4.13545, saving model to saved_models/weights.best.from_scratch.hdf5
# 334/334 [==============================] - 61s - loss: 4.0130 - acc: 0.0978 - val_loss: 4.1354 - val_acc: 0.0768
# Epoch 16/50
# 333/334 [============================>.] - ETA: 0s - loss: 3.9864 - acc: 0.1074Epoch 00015: val_loss improved from 4.13545 to 4.10308, saving model to saved_models/weights.best.from_scratch.hdf5
# 334/334 [==============================] - 60s - loss: 3.9874 - acc: 0.1072 - val_loss: 4.1031 - val_acc: 0.0939
# Epoch 17/50
# 333/334 [============================>.] - ETA: 0s - loss: 3.9489 - acc: 0.1057Epoch 00016: val_loss improved from 4.10308 to 4.04762, saving model to saved_models/weights.best.from_scratch.hdf5
# 334/334 [==============================] - 61s - loss: 3.9492 - acc: 0.1060 - val_loss: 4.0476 - val_acc: 0.0805
# Epoch 18/50
# 333/334 [============================>.] - ETA: 0s - loss: 3.8962 - acc: 0.1129Epoch 00017: val_loss did not improve
# 334/334 [==============================] - 60s - loss: 3.8959 - acc: 0.1127 - val_loss: 4.0762 - val_acc: 0.0915
# Epoch 19/50
# 333/334 [============================>.] - ETA: 0s - loss: 3.8570 - acc: 0.1134Epoch 00018: val_loss improved from 4.04762 to 4.01830, saving model to saved_models/weights.best.from_scratch.hdf5
# 334/334 [==============================] - 61s - loss: 3.8570 - acc: 0.1136 - val_loss: 4.0183 - val_acc: 0.1061
# Epoch 20/50
# 333/334 [============================>.] - ETA: 0s - loss: 3.8231 - acc: 0.1218Epoch 00019: val_loss improved from 4.01830 to 3.99227, saving model to saved_models/weights.best.from_scratch.hdf5
# 334/334 [==============================] - 61s - loss: 3.8235 - acc: 0.1216 - val_loss: 3.9923 - val_acc: 0.0854
# Epoch 21/50
# 333/334 [============================>.] - ETA: 0s - loss: 3.7821 - acc: 0.1329Epoch 00020: val_loss did not improve
# 334/334 [==============================] - 61s - loss: 3.7829 - acc: 0.1326 - val_loss: 3.9994 - val_acc: 0.0988
# Epoch 22/50
# 333/334 [============================>.] - ETA: 0s - loss: 3.7440 - acc: 0.1365Epoch 00021: val_loss did not improve
# 334/334 [==============================] - 61s - loss: 3.7428 - acc: 0.1367 - val_loss: 4.0197 - val_acc: 0.1049
# Epoch 23/50
# 333/334 [============================>.] - ETA: 0s - loss: 3.7229 - acc: 0.1369Epoch 00022: val_loss did not improve
# 334/334 [==============================] - 60s - loss: 3.7222 - acc: 0.1371 - val_loss: 4.0268 - val_acc: 0.1037
# Epoch 24/50
# 333/334 [============================>.] - ETA: 0s - loss: 3.7001 - acc: 0.1473Epoch 00023: val_loss improved from 3.99227 to 3.94209, saving model to saved_models/weights.best.from_scratch.hdf5
# 334/334 [==============================] - 61s - loss: 3.6991 - acc: 0.1476 - val_loss: 3.9421 - val_acc: 0.1183
# Epoch 25/50
# 333/334 [============================>.] - ETA: 0s - loss: 3.6603 - acc: 0.1498Epoch 00024: val_loss improved from 3.94209 to 3.91564, saving model to saved_models/weights.best.from_scratch.hdf5
# 334/334 [==============================] - 60s - loss: 3.6593 - acc: 0.1500 - val_loss: 3.9156 - val_acc: 0.1220
# Epoch 26/50
# 333/334 [============================>.] - ETA: 0s - loss: 3.6233 - acc: 0.1551Epoch 00025: val_loss improved from 3.91564 to 3.82960, saving model to saved_models/weights.best.from_scratch.hdf5
# 334/334 [==============================] - 60s - loss: 3.6228 - acc: 0.1549 - val_loss: 3.8296 - val_acc: 0.1122
# Epoch 27/50
# 333/334 [============================>.] - ETA: 0s - loss: 3.5929 - acc: 0.1568Epoch 00026: val_loss did not improve
# 334/334 [==============================] - 60s - loss: 3.5914 - acc: 0.1572 - val_loss: 3.9845 - val_acc: 0.1000
# Epoch 28/50
# 333/334 [============================>.] - ETA: 0s - loss: 3.5727 - acc: 0.1610Epoch 00027: val_loss improved from 3.82960 to 3.81086, saving model to saved_models/weights.best.from_scratch.hdf5
# 334/334 [==============================] - 61s - loss: 3.5726 - acc: 0.1612 - val_loss: 3.8109 - val_acc: 0.1232
# Epoch 29/50
# 333/334 [============================>.] - ETA: 0s - loss: 3.5314 - acc: 0.1659Epoch 00028: val_loss improved from 3.81086 to 3.75764, saving model to saved_models/weights.best.from_scratch.hdf5
# 334/334 [==============================] - 60s - loss: 3.5312 - acc: 0.1665 - val_loss: 3.7576 - val_acc: 0.1366
# Epoch 30/50
# 333/334 [============================>.] - ETA: 0s - loss: 3.5042 - acc: 0.1770Epoch 00029: val_loss did not improve
# 334/334 [==============================] - 61s - loss: 3.5028 - acc: 0.1775 - val_loss: 3.8417 - val_acc: 0.1207
# Epoch 31/50
# 333/334 [============================>.] - ETA: 0s - loss: 3.4814 - acc: 0.1767Epoch 00030: val_loss did not improve
# 334/334 [==============================] - 60s - loss: 3.4819 - acc: 0.1765 - val_loss: 3.8148 - val_acc: 0.1244
# Epoch 32/50
# 333/334 [============================>.] - ETA: 0s - loss: 3.4514 - acc: 0.1857Epoch 00031: val_loss improved from 3.75764 to 3.74767, saving model to saved_models/weights.best.from_scratch.hdf5
# 334/334 [==============================] - 60s - loss: 3.4515 - acc: 0.1858 - val_loss: 3.7477 - val_acc: 0.1427
# Epoch 33/50
# 333/334 [============================>.] - ETA: 0s - loss: 3.4124 - acc: 0.1911Epoch 00032: val_loss improved from 3.74767 to 3.66134, saving model to saved_models/weights.best.from_scratch.hdf5
# 334/334 [==============================] - 60s - loss: 3.4114 - acc: 0.1913 - val_loss: 3.6613 - val_acc: 0.1524
# Epoch 34/50
# 333/334 [============================>.] - ETA: 0s - loss: 3.3911 - acc: 0.1976Epoch 00033: val_loss improved from 3.66134 to 3.61750, saving model to saved_models/weights.best.from_scratch.hdf5
# 334/334 [==============================] - 60s - loss: 3.3929 - acc: 0.1975 - val_loss: 3.6175 - val_acc: 0.1732
# Epoch 35/50
# 333/334 [============================>.] - ETA: 0s - loss: 3.3661 - acc: 0.1931Epoch 00034: val_loss did not improve
# 334/334 [==============================] - 60s - loss: 3.3692 - acc: 0.1927 - val_loss: 3.8467 - val_acc: 0.1256
# Epoch 36/50
# 333/334 [============================>.] - ETA: 0s - loss: 3.3571 - acc: 0.2011Epoch 00035: val_loss did not improve
# 334/334 [==============================] - 60s - loss: 3.3551 - acc: 0.2013 - val_loss: 3.7279 - val_acc: 0.1476
# Epoch 37/50
# 333/334 [============================>.] - ETA: 0s - loss: 3.3256 - acc: 0.2017Epoch 00036: val_loss improved from 3.61750 to 3.60843, saving model to saved_models/weights.best.from_scratch.hdf5
# 334/334 [==============================] - 60s - loss: 3.3254 - acc: 0.2016 - val_loss: 3.6084 - val_acc: 0.1695
# Epoch 38/50
# 333/334 [============================>.] - ETA: 0s - loss: 3.2954 - acc: 0.2062Epoch 00037: val_loss did not improve
# 334/334 [==============================] - 60s - loss: 3.2951 - acc: 0.2061 - val_loss: 3.7337 - val_acc: 0.1646
# Epoch 39/50
# 333/334 [============================>.] - ETA: 0s - loss: 3.2769 - acc: 0.2138Epoch 00038: val_loss did not improve
# 334/334 [==============================] - 60s - loss: 3.2753 - acc: 0.2142 - val_loss: 3.6756 - val_acc: 0.1500
# Epoch 40/50
# 333/334 [============================>.] - ETA: 0s - loss: 3.2537 - acc: 0.2245Epoch 00039: val_loss did not improve
# 334/334 [==============================] - 60s - loss: 3.2531 - acc: 0.2247 - val_loss: 3.6249 - val_acc: 0.1646
# Epoch 41/50
# 333/334 [============================>.] - ETA: 0s - loss: 3.2330 - acc: 0.2218Epoch 00040: val_loss did not improve
# 334/334 [==============================] - 60s - loss: 3.2335 - acc: 0.2217 - val_loss: 3.6723 - val_acc: 0.1329
# Epoch 42/50
# 333/334 [============================>.] - ETA: 0s - loss: 3.2151 - acc: 0.2219Epoch 00041: val_loss improved from 3.60843 to 3.46970, saving model to saved_models/weights.best.from_scratch.hdf5
# 334/334 [==============================] - 61s - loss: 3.2165 - acc: 0.2216 - val_loss: 3.4697 - val_acc: 0.1671
# Epoch 43/50
# 333/334 [============================>.] - ETA: 0s - loss: 3.1823 - acc: 0.2353Epoch 00042: val_loss did not improve
# 334/334 [==============================] - 60s - loss: 3.1822 - acc: 0.2355 - val_loss: 3.5538 - val_acc: 0.1866
# Epoch 44/50
# 333/334 [============================>.] - ETA: 0s - loss: 3.1556 - acc: 0.2344Epoch 00043: val_loss did not improve
# 334/334 [==============================] - 61s - loss: 3.1551 - acc: 0.2346 - val_loss: 3.6549 - val_acc: 0.1951
# Epoch 45/50
# 333/334 [============================>.] - ETA: 0s - loss: 3.1341 - acc: 0.2395Epoch 00044: val_loss did not improve
# 334/334 [==============================] - 61s - loss: 3.1331 - acc: 0.2401 - val_loss: 3.5110 - val_acc: 0.1829
# Epoch 46/50
# 333/334 [============================>.] - ETA: 0s - loss: 3.1047 - acc: 0.2417Epoch 00045: val_loss improved from 3.46970 to 3.44346, saving model to saved_models/weights.best.from_scratch.hdf5
# 334/334 [==============================] - 61s - loss: 3.1078 - acc: 0.2415 - val_loss: 3.4435 - val_acc: 0.1659
# Epoch 47/50
# 333/334 [============================>.] - ETA: 0s - loss: 3.1080 - acc: 0.2390Epoch 00046: val_loss did not improve
# 334/334 [==============================] - 60s - loss: 3.1108 - acc: 0.2388 - val_loss: 3.7318 - val_acc: 0.1451
# Epoch 48/50
# 333/334 [============================>.] - ETA: 0s - loss: 3.0964 - acc: 0.2444Epoch 00047: val_loss did not improve
# 334/334 [==============================] - 60s - loss: 3.0967 - acc: 0.2442 - val_loss: 3.5274 - val_acc: 0.1732
# Epoch 49/50
# 333/334 [============================>.] - ETA: 0s - loss: 3.0653 - acc: 0.2539Epoch 00048: val_loss did not improve
# 334/334 [==============================] - 61s - loss: 3.0664 - acc: 0.2539 - val_loss: 3.5057 - val_acc: 0.1768
# Epoch 50/50
# 333/334 [============================>.] - ETA: 0s - loss: 3.0387 - acc: 0.2599Epoch 00049: val_loss improved from 3.44346 to 3.40550, saving model to saved_models/weights.best.from_scratch.hdf5
# 334/334 [==============================] - 61s - loss: 3.0406 - acc: 0.2596 - val_loss: 3.4055 - val_acc: 0.1890

# %% [markdown]
# ### Load the Model with the Best Validation Loss

# %%
model.load_weights('saved_models/weights.best.from_scratch.hdf5')

# %% [markdown]
# ### Test the Model
#
# Try out your model on the test dataset of dog images.  Ensure that your test accuracy is greater than 1%.

# %%
# get index of predicted dog breed for each image in test set
dog_breed_predictions = [np.argmax(model.predict(np.expand_dims(tensor, axis=0))) for tensor in test_tensors]

# report test accuracy
test_accuracy = 100*np.sum(np.array(dog_breed_predictions)==np.argmax(test_targets, axis=1))/len(dog_breed_predictions)
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 18.8995%

# %%
#Draw the weights
import math
for layer in model.get_weights():
    if layer.ndim == 4:
        x1w = layer[:,:,0,:]
        width = len(x1w[0][0])
        row =int(math.sqrt(width))+1
        colum =int(math.sqrt(width))+1
        for i in range(1,width):
            plt.subplot(row,colum,i)
            plt.axis('off')
            plt.imshow(x1w[:,:,i],interpolation="nearest",cmap="gray")
        plt.show()

# %% [markdown]
# ---
# <a id='step4'></a>
# ## Step 4: Use a CNN to Classify Dog Breeds
#
# To reduce training time without sacrificing accuracy, we show you how to train a CNN using transfer learning.  In the following step, you will get a chance to use transfer learning to train your own CNN.
#
# ### Obtain Bottleneck Features

# %%
bottleneck_features = np.load('bottleneck_features/DogVGG16Data.npz')
train_VGG16 = bottleneck_features['train']
valid_VGG16 = bottleneck_features['valid']
test_VGG16 = bottleneck_features['test']

# %% [markdown]
# ### Model Architecture
#
# The model uses the the pre-trained VGG-16 model as a fixed feature extractor, where the last convolutional output of VGG-16 is fed as input to our model.  We only add a global average pooling layer and a fully connected layer, where the latter contains one node for each dog category and is equipped with a softmax.

# %%
VGG16_model = Sequential()
VGG16_model.add(GlobalAveragePooling2D(input_shape=train_VGG16.shape[1:]))
VGG16_model.add(Dense(133, activation='softmax'))

VGG16_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# global_average_pooling2d_2 ( (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 133)               68229
# =================================================================
# Total params: 68,229
# Trainable params: 68,229
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Compile the Model

# %%
VGG16_model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# %% [markdown]
# ### Train the Model

# %%
checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.VGG16.hdf5', 
                               verbose=1, save_best_only=True)

VGG16_model.fit(train_VGG16, train_targets, 
          validation_data=(valid_VGG16, valid_targets),
          epochs=20, batch_size=20, callbacks=[checkpointer], verbose=1)
# Out:
# Train on 6680 samples, validate on 835 samples
# Epoch 1/20
# 6580/6680 [============================>.] - ETA: 0s - loss: 12.6357 - acc: 0.1070Epoch 00000: val_loss improved from inf to 11.06453, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 12.6249 - acc: 0.1078 - val_loss: 11.0645 - val_acc: 0.1880
# Epoch 2/20
# 6600/6680 [============================>.] - ETA: 0s - loss: 10.5199 - acc: 0.2467Epoch 00001: val_loss improved from 11.06453 to 10.36703, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 10.5259 - acc: 0.2466 - val_loss: 10.3670 - val_acc: 0.2623
# Epoch 3/20
# 6600/6680 [============================>.] - ETA: 0s - loss: 10.0345 - acc: 0.3076Epoch 00002: val_loss improved from 10.36703 to 10.25172, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 10.0320 - acc: 0.3081 - val_loss: 10.2517 - val_acc: 0.2814
# Epoch 4/20
# 6580/6680 [============================>.] - ETA: 0s - loss: 9.8144 - acc: 0.3418Epoch 00003: val_loss improved from 10.25172 to 10.13563, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 9.8328 - acc: 0.3406 - val_loss: 10.1356 - val_acc: 0.2958
# Epoch 5/20
# 6620/6680 [============================>.] - ETA: 0s - loss: 9.6760 - acc: 0.3606Epoch 00004: val_loss improved from 10.13563 to 10.10114, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 9.6922 - acc: 0.3597 - val_loss: 10.1011 - val_acc: 0.3042
# Epoch 6/20
# 6660/6680 [============================>.] - ETA: 0s - loss: 9.6047 - acc: 0.3746Epoch 00005: val_loss improved from 10.10114 to 10.08251, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 9.5985 - acc: 0.3747 - val_loss: 10.0825 - val_acc: 0.3114
# Epoch 7/20
# 6560/6680 [============================>.] - ETA: 0s - loss: 9.4675 - acc: 0.3846Epoch 00006: val_loss improved from 10.08251 to 9.86586, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 9.4583 - acc: 0.3844 - val_loss: 9.8659 - val_acc: 0.3305
# Epoch 8/20
# 6600/6680 [============================>.] - ETA: 0s - loss: 9.1855 - acc: 0.4012Epoch 00007: val_loss improved from 9.86586 to 9.68653, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 9.2063 - acc: 0.4000 - val_loss: 9.6865 - val_acc: 0.3126
# Epoch 9/20
# 6600/6680 [============================>.] - ETA: 0s - loss: 9.0057 - acc: 0.4198Epoch 00008: val_loss improved from 9.68653 to 9.53216, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 8.9838 - acc: 0.4211 - val_loss: 9.5322 - val_acc: 0.3461
# Epoch 10/20
# 6640/6680 [============================>.] - ETA: 0s - loss: 8.9245 - acc: 0.4316Epoch 00009: val_loss improved from 9.53216 to 9.48018, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 8.9291 - acc: 0.4314 - val_loss: 9.4802 - val_acc: 0.3389
# Epoch 11/20
# 6640/6680 [============================>.] - ETA: 0s - loss: 8.8501 - acc: 0.4343Epoch 00010: val_loss improved from 9.48018 to 9.34807, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 8.8598 - acc: 0.4338 - val_loss: 9.3481 - val_acc: 0.3509
# Epoch 12/20
# 6620/6680 [============================>.] - ETA: 0s - loss: 8.6801 - acc: 0.4446Epoch 00011: val_loss improved from 9.34807 to 9.32517, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 8.6723 - acc: 0.4452 - val_loss: 9.3252 - val_acc: 0.3509
# Epoch 13/20
# 6540/6680 [============================>.] - ETA: 0s - loss: 8.5912 - acc: 0.4535Epoch 00012: val_loss improved from 9.32517 to 9.29576, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 8.5906 - acc: 0.4536 - val_loss: 9.2958 - val_acc: 0.3557
# Epoch 14/20
# 6640/6680 [============================>.] - ETA: 0s - loss: 8.5017 - acc: 0.4599Epoch 00013: val_loss improved from 9.29576 to 9.16859, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 8.4971 - acc: 0.4602 - val_loss: 9.1686 - val_acc: 0.3617
# Epoch 15/20
# 6600/6680 [============================>.] - ETA: 0s - loss: 8.3649 - acc: 0.4688Epoch 00014: val_loss improved from 9.16859 to 9.12946, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 8.3940 - acc: 0.4669 - val_loss: 9.1295 - val_acc: 0.3725
# Epoch 16/20
# 6620/6680 [============================>.] - ETA: 0s - loss: 8.3412 - acc: 0.4734Epoch 00015: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 8.3322 - acc: 0.4738 - val_loss: 9.2009 - val_acc: 0.3689
# Epoch 17/20
# 6620/6680 [============================>.] - ETA: 0s - loss: 8.2843 - acc: 0.4761Epoch 00016: val_loss improved from 9.12946 to 9.02949, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 8.2871 - acc: 0.4760 - val_loss: 9.0295 - val_acc: 0.3737
# Epoch 18/20
# 6640/6680 [============================>.] - ETA: 0s - loss: 8.1761 - acc: 0.4828Epoch 00017: val_loss improved from 9.02949 to 8.90187, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 8.1754 - acc: 0.4829 - val_loss: 8.9019 - val_acc: 0.3844
# Epoch 19/20
# 6540/6680 [============================>.] - ETA: 0s - loss: 8.1448 - acc: 0.4856Epoch 00018: val_loss improved from 8.90187 to 8.86114, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 8.1357 - acc: 0.4864 - val_loss: 8.8611 - val_acc: 0.3832
# Epoch 20/20
# 6580/6680 [============================>.] - ETA: 0s - loss: 8.1001 - acc: 0.4912Epoch 00019: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 8.0922 - acc: 0.4916 - val_loss: 8.9225 - val_acc: 0.3844

# %% [markdown]
# ### Load the Model with the Best Validation Loss

# %%
VGG16_model.load_weights('saved_models/weights.best.VGG16.hdf5')

# %% [markdown]
# ### Test the Model
#
# Now, we can use the CNN to test how well it identifies breed within our test dataset of dog images.  We print the test accuracy below.

# %%
# get index of predicted dog breed for each image in test set
VGG16_predictions = [np.argmax(VGG16_model.predict(np.expand_dims(feature, axis=0))) for feature in test_VGG16]

# report test accuracy
test_accuracy = 100*np.sum(np.array(VGG16_predictions)==np.argmax(test_targets, axis=1))/len(VGG16_predictions)
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 39.3541%

# %% [markdown]
# ### Predict Dog Breed with the Model

# %%
from extract_bottleneck_features import *

def VGG16_predict_breed(img_path):
    # extract bottleneck features
    bottleneck_feature = extract_VGG16(path_to_tensor(img_path))
    # obtain predicted vector
    predicted_vector = VGG16_model.predict(bottleneck_feature)
    # return dog breed that is predicted by the model
    return dog_names[np.argmax(predicted_vector)]

# %% [markdown]
# ---
# <a id='step5'></a>
# ## Step 5: Create a CNN to Classify Dog Breeds (using Transfer Learning)
#
# You will now use transfer learning to create a CNN that can identify dog breed from images.  Your CNN must attain at least 60% accuracy on the test set.
#
# In Step 4, we used transfer learning to create a CNN using VGG-16 bottleneck features.  In this section, you must use the bottleneck features from a different pre-trained model.  To make things easier for you, we have pre-computed the features for all of the networks that are currently available in Keras:
# - [VGG-19](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogVGG19Data.npz) bottleneck features
# - [ResNet-50](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogResnet50Data.npz) bottleneck features
# - [Inception](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogInceptionV3Data.npz) bottleneck features
# - [Xception](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogXceptionData.npz) bottleneck features
#
# The files are encoded as such:
#
#     Dog{network}Data.npz
#
# where `{network}`, in the above filename, can be one of `VGG19`, `Resnet50`, `InceptionV3`, or `Xception`.  Pick one of the above architectures, download the corresponding bottleneck features, and store the downloaded file in the `bottleneck_features/` folder in the repository.
#
# ### (IMPLEMENTATION) Obtain Bottleneck Features
#
# In the code block below, extract the bottleneck features corresponding to the train, test, and validation sets by running the following:
#
#     bottleneck_features = np.load('bottleneck_features/Dog{network}Data.npz')
#     train_{network} = bottleneck_features['train']
#     valid_{network} = bottleneck_features['valid']
#     test_{network} = bottleneck_features['test']

# %%
### TODO: Obtain bottleneck features from another pre-trained CNN.
bottleneck_features = np.load('bottleneck_features/DogVGG16Data.npz')
train_VGG16 = bottleneck_features['train']
valid_VGG16 = bottleneck_features['valid']
test_VGG16 = bottleneck_features['test']

# %% [markdown]
# ### (IMPLEMENTATION) Model Architecture
#
# Create a CNN to classify dog breed.  At the end of your code cell block, summarize the layers of your model by executing the line:
#
#         <your model's name>.summary()
#
# __Question 5:__ Outline the steps you took to get to your final CNN architecture and your reasoning at each step.  Describe why you think the architecture is suitable for the current problem.
#
# __Answer:__

# %%
### TODO: Define your architecture.
model1 = Sequential()

### TODO: Define your architecture.
model1.add(Conv2D(filters=16, kernel_size=2, strides=1,padding='valid',activation='relu',input_shape=train_VGG16[0].shape))
model1.add(MaxPooling2D(pool_size=(2,2)))
model1.add(GlobalAveragePooling2D())
model1.add(Dense(133, activation='softmax'))

model1.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 6, 6, 16)          32784
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 3, 3, 16)          0
# _________________________________________________________________
# global_average_pooling2d_2 ( (None, 16)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 133)               2261
# =================================================================
# Total params: 35,045
# Trainable params: 35,045
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### (IMPLEMENTATION) Compile the Model

# %%
### TODO: Compile the model.
model1.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# %% [markdown]
# ### (IMPLEMENTATION) Train the Model
#
# Train your model in the code cell below.  Use model checkpointing to save the model that attains the best validation loss.
#
# You are welcome to [augment the training data](https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html), but this is not a requirement.

# %%
### TODO: Train the model.
from keras.callbacks import ModelCheckpoint  
from keras.preprocessing.image import ImageDataGenerator

### TODO: specify the number of epochs that you would like to use to train the model

batch_size = 20
epochs = 50
### Do NOT modify the code below this line.

checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.from_scratch.hdf5', 
                               verbose=1, save_best_only=True)

model1.fit(train_VGG16, train_targets, 
          validation_data=(valid_VGG16, valid_targets),
          epochs=20, batch_size=20, callbacks=[checkpointer], verbose=1)
# Out:
# Train on 6680 samples, validate on 835 samples
# Epoch 1/20
# 6620/6680 [============================>.] - ETA: 185s - loss: 15.0026 - acc: 0.0000e+ - ETA: 50s - loss: 15.0164 - acc: 0.0250     - ETA: 31s - loss: 14.3155 - acc: 0.028 - ETA: 23s - loss: 12.0359 - acc: 0.030 - ETA: 18s - loss: 10.0905 - acc: 0.021 - ETA: 14s - loss: 8.9672 - acc: 0.019 - ETA: 12s - loss: 8.2429 - acc: 0.01 - ETA: 11s - loss: 7.8479 - acc: 0.01 - ETA: 11s - loss: 7.5376 - acc: 0.01 - ETA: 10s - loss: 7.2816 - acc: 0.01 - ETA: 9s - loss: 7.0754 - acc: 0.0132 - ETA: 9s - loss: 6.8992 - acc: 0.013 - ETA: 9s - loss: 6.7514 - acc: 0.012 - ETA: 8s - loss: 6.5850 - acc: 0.011 - ETA: 8s - loss: 6.4418 - acc: 0.011 - ETA: 7s - loss: 6.3196 - acc: 0.013 - ETA: 7s - loss: 6.2397 - acc: 0.013 - ETA: 7s - loss: 6.1706 - acc: 0.012 - ETA: 7s - loss: 6.1051 - acc: 0.015 - ETA: 6s - loss: 6.0469 - acc: 0.015 - ETA: 6s - loss: 5.9735 - acc: 0.015 - ETA: 6s - loss: 5.9065 - acc: 0.017 - ETA: 6s - loss: 5.8665 - acc: 0.019 - ETA: 6s - loss: 5.8103 - acc: 0.018 - ETA: 5s - loss: 5.7790 - acc: 0.018 - ETA: 5s - loss: 5.7418 - acc: 0.019 - ETA: 5s - loss: 5.7129 - acc: 0.019 - ETA: 5s - loss: 5.6819 - acc: 0.020 - ETA: 5s - loss: 5.6523 - acc: 0.020 - ETA: 5s - loss: 5.6172 - acc: 0.021 - ETA: 5s - loss: 5.5977 - acc: 0.020 - ETA: 5s - loss: 5.5806 - acc: 0.020 - ETA: 5s - loss: 5.5513 - acc: 0.021 - ETA: 4s - loss: 5.5277 - acc: 0.021 - ETA: 4s - loss: 5.5004 - acc: 0.022 - ETA: 4s - loss: 5.4787 - acc: 0.022 - ETA: 4s - loss: 5.4597 - acc: 0.022 - ETA: 4s - loss: 5.4406 - acc: 0.023 - ETA: 4s - loss: 5.4241 - acc: 0.022 - ETA: 4s - loss: 5.4082 - acc: 0.023 - ETA: 4s - loss: 5.3899 - acc: 0.024 - ETA: 4s - loss: 5.3774 - acc: 0.024 - ETA: 4s - loss: 5.3525 - acc: 0.027 - ETA: 3s - loss: 5.3360 - acc: 0.028 - ETA: 3s - loss: 5.3174 - acc: 0.029 - ETA: 3s - loss: 5.2962 - acc: 0.031 - ETA: 3s - loss: 5.2820 - acc: 0.032 - ETA: 3s - loss: 5.2652 - acc: 0.033 - ETA: 3s - loss: 5.2541 - acc: 0.033 - ETA: 3s - loss: 5.2408 - acc: 0.034 - ETA: 3s - loss: 5.2262 - acc: 0.035 - ETA: 3s - loss: 5.2060 - acc: 0.036 - ETA: 3s - loss: 5.1891 - acc: 0.037 - ETA: 3s - loss: 5.1787 - acc: 0.038 - ETA: 3s - loss: 5.1664 - acc: 0.039 - ETA: 2s - loss: 5.1525 - acc: 0.040 - ETA: 2s - loss: 5.1349 - acc: 0.042 - ETA: 2s - loss: 5.1168 - acc: 0.043 - ETA: 2s - loss: 5.1121 - acc: 0.044 - ETA: 2s - loss: 5.1025 - acc: 0.045 - ETA: 2s - loss: 5.0877 - acc: 0.046 - ETA: 2s - loss: 5.0738 - acc: 0.047 - ETA: 2s - loss: 5.0616 - acc: 0.048 - ETA: 2s - loss: 5.0542 - acc: 0.047 - ETA: 2s - loss: 5.0418 - acc: 0.048 - ETA: 2s - loss: 5.0332 - acc: 0.048 - ETA: 2s - loss: 5.0207 - acc: 0.048 - ETA: 2s - loss: 5.0076 - acc: 0.049 - ETA: 2s - loss: 5.0011 - acc: 0.050 - ETA: 1s - loss: 4.9933 - acc: 0.050 - ETA: 1s - loss: 4.9831 - acc: 0.051 - ETA: 1s - loss: 4.9718 - acc: 0.052 - ETA: 1s - loss: 4.9644 - acc: 0.052 - ETA: 1s - loss: 4.9544 - acc: 0.052 - ETA: 1s - loss: 4.9505 - acc: 0.052 - ETA: 1s - loss: 4.9405 - acc: 0.053 - ETA: 1s - loss: 4.9287 - acc: 0.054 - ETA: 1s - loss: 4.9169 - acc: 0.055 - ETA: 1s - loss: 4.9086 - acc: 0.054 - ETA: 1s - loss: 4.9004 - acc: 0.055 - ETA: 1s - loss: 4.8917 - acc: 0.056 - ETA: 1s - loss: 4.8796 - acc: 0.057 - ETA: 1s - loss: 4.8712 - acc: 0.058 - ETA: 1s - loss: 4.8586 - acc: 0.059 - ETA: 1s - loss: 4.8523 - acc: 0.059 - ETA: 1s - loss: 4.8418 - acc: 0.060 - ETA: 0s - loss: 4.8320 - acc: 0.062 - ETA: 0s - loss: 4.8229 - acc: 0.063 - ETA: 0s - loss: 4.8176 - acc: 0.063 - ETA: 0s - loss: 4.8056 - acc: 0.064 - ETA: 0s - loss: 4.8002 - acc: 0.064 - ETA: 0s - loss: 4.7901 - acc: 0.065 - ETA: 0s - loss: 4.7818 - acc: 0.065 - ETA: 0s - loss: 4.7742 - acc: 0.066 - ETA: 0s - loss: 4.7687 - acc: 0.067 - ETA: 0s - loss: 4.7602 - acc: 0.067 - ETA: 0s - loss: 4.7507 - acc: 0.068 - ETA: 0s - loss: 4.7391 - acc: 0.069 - ETA: 0s - loss: 4.7311 - acc: 0.069 - ETA: 0s - loss: 4.7246 - acc: 0.070 - ETA: 0s - loss: 4.7192 - acc: 0.071 - ETA: 0s - loss: 4.7094 - acc: 0.073 - ETA: 0s - loss: 4.7013 - acc: 0.0742Epoch 00000: val_loss  ...
# 6680/6680 [==============================] - 7s - loss: 4.6940 - acc: 0.0753 - val_loss: 3.8154 - val_acc: 0.1509
# Epoch 2/20
# 6620/6680 [============================>.] - ETA: 5s - loss: 3.1800 - acc: 0.250 - ETA: 4s - loss: 3.5146 - acc: 0.160 - ETA: 4s - loss: 3.6030 - acc: 0.177 - ETA: 4s - loss: 3.5589 - acc: 0.180 - ETA: 4s - loss: 3.6043 - acc: 0.171 - ETA: 4s - loss: 3.5276 - acc: 0.175 - ETA: 5s - loss: 3.5714 - acc: 0.172 - ETA: 4s - loss: 3.5648 - acc: 0.180 - ETA: 4s - loss: 3.5662 - acc: 0.171 - ETA: 4s - loss: 3.5576 - acc: 0.180 - ETA: 4s - loss: 3.5721 - acc: 0.176 - ETA: 4s - loss: 3.5717 - acc: 0.179 - ETA: 4s - loss: 3.5757 - acc: 0.183 - ETA: 4s - loss: 3.5945 - acc: 0.178 - ETA: 4s - loss: 3.5680 - acc: 0.183 - ETA: 4s - loss: 3.5596 - acc: 0.182 - ETA: 4s - loss: 3.5587 - acc: 0.183 - ETA: 4s - loss: 3.5294 - acc: 0.187 - ETA: 4s - loss: 3.5372 - acc: 0.185 - ETA: 4s - loss: 3.5430 - acc: 0.185 - ETA: 4s - loss: 3.5406 - acc: 0.184 - ETA: 4s - loss: 3.5305 - acc: 0.188 - ETA: 4s - loss: 3.4974 - acc: 0.192 - ETA: 4s - loss: 3.4937 - acc: 0.190 - ETA: 4s - loss: 3.4899 - acc: 0.190 - ETA: 4s - loss: 3.4855 - acc: 0.191 - ETA: 4s - loss: 3.4809 - acc: 0.194 - ETA: 4s - loss: 3.4819 - acc: 0.195 - ETA: 4s - loss: 3.4645 - acc: 0.197 - ETA: 4s - loss: 3.4657 - acc: 0.198 - ETA: 4s - loss: 3.4597 - acc: 0.198 - ETA: 4s - loss: 3.4458 - acc: 0.200 - ETA: 4s - loss: 3.4373 - acc: 0.202 - ETA: 4s - loss: 3.4352 - acc: 0.202 - ETA: 4s - loss: 3.4275 - acc: 0.204 - ETA: 4s - loss: 3.4253 - acc: 0.206 - ETA: 4s - loss: 3.4201 - acc: 0.207 - ETA: 4s - loss: 3.4261 - acc: 0.208 - ETA: 4s - loss: 3.4261 - acc: 0.208 - ETA: 3s - loss: 3.4209 - acc: 0.209 - ETA: 3s - loss: 3.4048 - acc: 0.213 - ETA: 3s - loss: 3.3984 - acc: 0.215 - ETA: 3s - loss: 3.3906 - acc: 0.218 - ETA: 3s - loss: 3.3871 - acc: 0.217 - ETA: 3s - loss: 3.3741 - acc: 0.221 - ETA: 3s - loss: 3.3669 - acc: 0.222 - ETA: 3s - loss: 3.3569 - acc: 0.223 - ETA: 3s - loss: 3.3564 - acc: 0.223 - ETA: 3s - loss: 3.3472 - acc: 0.226 - ETA: 3s - loss: 3.3475 - acc: 0.226 - ETA: 3s - loss: 3.3427 - acc: 0.226 - ETA: 3s - loss: 3.3434 - acc: 0.226 - ETA: 3s - loss: 3.3414 - acc: 0.226 - ETA: 3s - loss: 3.3306 - acc: 0.228 - ETA: 3s - loss: 3.3203 - acc: 0.229 - ETA: 3s - loss: 3.3182 - acc: 0.229 - ETA: 3s - loss: 3.3112 - acc: 0.231 - ETA: 2s - loss: 3.3058 - acc: 0.231 - ETA: 2s - loss: 3.2945 - acc: 0.234 - ETA: 2s - loss: 3.2933 - acc: 0.234 - ETA: 2s - loss: 3.2892 - acc: 0.235 - ETA: 2s - loss: 3.2826 - acc: 0.236 - ETA: 2s - loss: 3.2832 - acc: 0.236 - ETA: 2s - loss: 3.2793 - acc: 0.237 - ETA: 2s - loss: 3.2757 - acc: 0.239 - ETA: 2s - loss: 3.2650 - acc: 0.241 - ETA: 2s - loss: 3.2687 - acc: 0.241 - ETA: 2s - loss: 3.2622 - acc: 0.242 - ETA: 2s - loss: 3.2588 - acc: 0.244 - ETA: 2s - loss: 3.2587 - acc: 0.242 - ETA: 2s - loss: 3.2547 - acc: 0.242 - ETA: 2s - loss: 3.2477 - acc: 0.244 - ETA: 2s - loss: 3.2476 - acc: 0.244 - ETA: 1s - loss: 3.2390 - acc: 0.244 - ETA: 1s - loss: 3.2291 - acc: 0.245 - ETA: 1s - loss: 3.2229 - acc: 0.246 - ETA: 1s - loss: 3.2142 - acc: 0.248 - ETA: 1s - loss: 3.2054 - acc: 0.250 - ETA: 1s - loss: 3.2019 - acc: 0.250 - ETA: 1s - loss: 3.1884 - acc: 0.251 - ETA: 1s - loss: 3.1857 - acc: 0.253 - ETA: 1s - loss: 3.1808 - acc: 0.253 - ETA: 1s - loss: 3.1732 - acc: 0.254 - ETA: 1s - loss: 3.1714 - acc: 0.256 - ETA: 1s - loss: 3.1644 - acc: 0.258 - ETA: 1s - loss: 3.1605 - acc: 0.259 - ETA: 1s - loss: 3.1556 - acc: 0.260 - ETA: 1s - loss: 3.1512 - acc: 0.260 - ETA: 0s - loss: 3.1476 - acc: 0.260 - ETA: 0s - loss: 3.1434 - acc: 0.261 - ETA: 0s - loss: 3.1338 - acc: 0.263 - ETA: 0s - loss: 3.1272 - acc: 0.264 - ETA: 0s - loss: 3.1245 - acc: 0.265 - ETA: 0s - loss: 3.1211 - acc: 0.265 - ETA: 0s - loss: 3.1191 - acc: 0.265 - ETA: 0s - loss: 3.1102 - acc: 0.267 - ETA: 0s - loss: 3.1045 - acc: 0.268 - ETA: 0s - loss: 3.1019 - acc: 0.269 - ETA: 0s - loss: 3.0952 - acc: 0.270 - ETA: 0s - loss: 3.0939 - acc: 0.270 - ETA: 0s - loss: 3.0885 - acc: 0.271 - ETA: 0s - loss: 3.0810 - acc: 0.272 - ETA: 0s - loss: 3.0768 - acc: 0.2740Epoch 00001: val_loss improved from 3.81541 ...
# 6680/6680 [==============================] - 6s - loss: 3.0704 - acc: 0.2751 - val_loss: 2.7304 - val_acc: 0.3257
# Epoch 3/20
# 6640/6680 [============================>.] - ETA: 4s - loss: 2.6729 - acc: 0.450 - ETA: 5s - loss: 2.4885 - acc: 0.360 - ETA: 5s - loss: 2.3905 - acc: 0.411 - ETA: 5s - loss: 2.3236 - acc: 0.392 - ETA: 5s - loss: 2.3042 - acc: 0.396 - ETA: 4s - loss: 2.2521 - acc: 0.400 - ETA: 4s - loss: 2.2476 - acc: 0.429 - ETA: 4s - loss: 2.2279 - acc: 0.430 - ETA: 4s - loss: 2.1839 - acc: 0.435 - ETA: 4s - loss: 2.1992 - acc: 0.431 - ETA: 4s - loss: 2.1913 - acc: 0.426 - ETA: 4s - loss: 2.1970 - acc: 0.422 - ETA: 4s - loss: 2.2076 - acc: 0.418 - ETA: 4s - loss: 2.1975 - acc: 0.422 - ETA: 4s - loss: 2.2079 - acc: 0.419 - ETA: 4s - loss: 2.1645 - acc: 0.424 - ETA: 4s - loss: 2.1632 - acc: 0.423 - ETA: 4s - loss: 2.1509 - acc: 0.423 - ETA: 4s - loss: 2.1560 - acc: 0.423 - ETA: 4s - loss: 2.1567 - acc: 0.425 - ETA: 4s - loss: 2.1675 - acc: 0.422 - ETA: 4s - loss: 2.1530 - acc: 0.428 - ETA: 4s - loss: 2.1504 - acc: 0.428 - ETA: 4s - loss: 2.1259 - acc: 0.433 - ETA: 4s - loss: 2.1261 - acc: 0.434 - ETA: 4s - loss: 2.1230 - acc: 0.433 - ETA: 3s - loss: 2.1338 - acc: 0.432 - ETA: 3s - loss: 2.1295 - acc: 0.433 - ETA: 3s - loss: 2.1268 - acc: 0.434 - ETA: 3s - loss: 2.1271 - acc: 0.436 - ETA: 3s - loss: 2.1188 - acc: 0.436 - ETA: 3s - loss: 2.1123 - acc: 0.438 - ETA: 3s - loss: 2.1112 - acc: 0.439 - ETA: 3s - loss: 2.1000 - acc: 0.442 - ETA: 3s - loss: 2.0943 - acc: 0.444 - ETA: 3s - loss: 2.0962 - acc: 0.444 - ETA: 3s - loss: 2.0935 - acc: 0.444 - ETA: 3s - loss: 2.0962 - acc: 0.443 - ETA: 3s - loss: 2.0924 - acc: 0.444 - ETA: 3s - loss: 2.1005 - acc: 0.442 - ETA: 3s - loss: 2.1037 - acc: 0.443 - ETA: 3s - loss: 2.1027 - acc: 0.443 - ETA: 3s - loss: 2.1017 - acc: 0.444 - ETA: 3s - loss: 2.0999 - acc: 0.444 - ETA: 3s - loss: 2.0979 - acc: 0.444 - ETA: 3s - loss: 2.0966 - acc: 0.443 - ETA: 3s - loss: 2.0888 - acc: 0.446 - ETA: 2s - loss: 2.0812 - acc: 0.448 - ETA: 2s - loss: 2.0763 - acc: 0.449 - ETA: 2s - loss: 2.0749 - acc: 0.450 - ETA: 2s - loss: 2.0720 - acc: 0.451 - ETA: 2s - loss: 2.0695 - acc: 0.452 - ETA: 2s - loss: 2.0691 - acc: 0.451 - ETA: 2s - loss: 2.0618 - acc: 0.453 - ETA: 2s - loss: 2.0650 - acc: 0.454 - ETA: 2s - loss: 2.0607 - acc: 0.454 - ETA: 2s - loss: 2.0554 - acc: 0.456 - ETA: 2s - loss: 2.0562 - acc: 0.456 - ETA: 2s - loss: 2.0623 - acc: 0.455 - ETA: 2s - loss: 2.0677 - acc: 0.454 - ETA: 2s - loss: 2.0697 - acc: 0.454 - ETA: 2s - loss: 2.0785 - acc: 0.453 - ETA: 2s - loss: 2.0754 - acc: 0.454 - ETA: 2s - loss: 2.0808 - acc: 0.453 - ETA: 2s - loss: 2.0771 - acc: 0.453 - ETA: 2s - loss: 2.0746 - acc: 0.454 - ETA: 1s - loss: 2.0774 - acc: 0.453 - ETA: 1s - loss: 2.0711 - acc: 0.454 - ETA: 1s - loss: 2.0715 - acc: 0.454 - ETA: 1s - loss: 2.0625 - acc: 0.456 - ETA: 1s - loss: 2.0573 - acc: 0.457 - ETA: 1s - loss: 2.0499 - acc: 0.458 - ETA: 1s - loss: 2.0464 - acc: 0.459 - ETA: 1s - loss: 2.0512 - acc: 0.458 - ETA: 1s - loss: 2.0483 - acc: 0.460 - ETA: 1s - loss: 2.0417 - acc: 0.461 - ETA: 1s - loss: 2.0474 - acc: 0.460 - ETA: 1s - loss: 2.0406 - acc: 0.462 - ETA: 0s - loss: 2.0381 - acc: 0.462 - ETA: 0s - loss: 2.0365 - acc: 0.464 - ETA: 0s - loss: 2.0329 - acc: 0.464 - ETA: 0s - loss: 2.0248 - acc: 0.465 - ETA: 0s - loss: 2.0245 - acc: 0.466 - ETA: 0s - loss: 2.0241 - acc: 0.466 - ETA: 0s - loss: 2.0263 - acc: 0.466 - ETA: 0s - loss: 2.0258 - acc: 0.466 - ETA: 0s - loss: 2.0228 - acc: 0.466 - ETA: 0s - loss: 2.0215 - acc: 0.466 - ETA: 0s - loss: 2.0132 - acc: 0.468 - ETA: 0s - loss: 2.0133 - acc: 0.468 - ETA: 0s - loss: 2.0142 - acc: 0.467 - ETA: 0s - loss: 2.0126 - acc: 0.468 - ETA: 0s - loss: 2.0068 - acc: 0.4691Epoch 00002: val_loss improved from 2.73037 to 2.25076, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 5s - loss: 2.0066 - acc: 0.4693 - val_loss: 2.2508 - val_acc: 0.4311
# Epoch 4/20
# 6660/6680 [============================>.] - ETA: 3s - loss: 1.5524 - acc: 0.550 - ETA: 6s - loss: 1.5610 - acc: 0.550 - ETA: 5s - loss: 1.4463 - acc: 0.578 - ETA: 6s - loss: 1.3930 - acc: 0.585 - ETA: 6s - loss: 1.4076 - acc: 0.580 - ETA: 5s - loss: 1.3482 - acc: 0.611 - ETA: 5s - loss: 1.4197 - acc: 0.604 - ETA: 5s - loss: 1.4237 - acc: 0.606 - ETA: 5s - loss: 1.3982 - acc: 0.615 - ETA: 5s - loss: 1.4485 - acc: 0.603 - ETA: 5s - loss: 1.4566 - acc: 0.606 - ETA: 5s - loss: 1.4467 - acc: 0.607 - ETA: 5s - loss: 1.4703 - acc: 0.609 - ETA: 5s - loss: 1.4633 - acc: 0.603 - ETA: 5s - loss: 1.4967 - acc: 0.596 - ETA: 4s - loss: 1.4964 - acc: 0.594 - ETA: 4s - loss: 1.5019 - acc: 0.592 - ETA: 4s - loss: 1.4894 - acc: 0.591 - ETA: 4s - loss: 1.4777 - acc: 0.590 - ETA: 4s - loss: 1.4347 - acc: 0.600 - ETA: 4s - loss: 1.4140 - acc: 0.605 - ETA: 4s - loss: 1.4106 - acc: 0.608 - ETA: 4s - loss: 1.4169 - acc: 0.606 - ETA: 3s - loss: 1.4150 - acc: 0.608 - ETA: 4s - loss: 1.4176 - acc: 0.607 - ETA: 3s - loss: 1.4260 - acc: 0.604 - ETA: 3s - loss: 1.4260 - acc: 0.607 - ETA: 3s - loss: 1.4403 - acc: 0.601 - ETA: 3s - loss: 1.4418 - acc: 0.602 - ETA: 3s - loss: 1.4508 - acc: 0.602 - ETA: 3s - loss: 1.4536 - acc: 0.602 - ETA: 3s - loss: 1.4614 - acc: 0.601 - ETA: 3s - loss: 1.4707 - acc: 0.597 - ETA: 3s - loss: 1.4733 - acc: 0.596 - ETA: 3s - loss: 1.4712 - acc: 0.596 - ETA: 3s - loss: 1.4674 - acc: 0.594 - ETA: 3s - loss: 1.4621 - acc: 0.595 - ETA: 3s - loss: 1.4561 - acc: 0.598 - ETA: 3s - loss: 1.4476 - acc: 0.598 - ETA: 3s - loss: 1.4476 - acc: 0.598 - ETA: 3s - loss: 1.4476 - acc: 0.598 - ETA: 3s - loss: 1.4461 - acc: 0.599 - ETA: 3s - loss: 1.4476 - acc: 0.598 - ETA: 3s - loss: 1.4499 - acc: 0.597 - ETA: 3s - loss: 1.4433 - acc: 0.597 - ETA: 3s - loss: 1.4438 - acc: 0.597 - ETA: 3s - loss: 1.4383 - acc: 0.598 - ETA: 3s - loss: 1.4415 - acc: 0.597 - ETA: 3s - loss: 1.4395 - acc: 0.598 - ETA: 3s - loss: 1.4406 - acc: 0.598 - ETA: 3s - loss: 1.4401 - acc: 0.596 - ETA: 3s - loss: 1.4370 - acc: 0.596 - ETA: 3s - loss: 1.4296 - acc: 0.597 - ETA: 3s - loss: 1.4305 - acc: 0.597 - ETA: 3s - loss: 1.4289 - acc: 0.596 - ETA: 2s - loss: 1.4256 - acc: 0.599 - ETA: 2s - loss: 1.4244 - acc: 0.599 - ETA: 2s - loss: 1.4233 - acc: 0.600 - ETA: 2s - loss: 1.4170 - acc: 0.601 - ETA: 2s - loss: 1.4253 - acc: 0.599 - ETA: 2s - loss: 1.4270 - acc: 0.599 - ETA: 2s - loss: 1.4213 - acc: 0.599 - ETA: 2s - loss: 1.4192 - acc: 0.600 - ETA: 2s - loss: 1.4172 - acc: 0.601 - ETA: 2s - loss: 1.4207 - acc: 0.601 - ETA: 2s - loss: 1.4158 - acc: 0.603 - ETA: 2s - loss: 1.4095 - acc: 0.604 - ETA: 2s - loss: 1.4092 - acc: 0.606 - ETA: 2s - loss: 1.4098 - acc: 0.605 - ETA: 2s - loss: 1.4104 - acc: 0.604 - ETA: 2s - loss: 1.4102 - acc: 0.604 - ETA: 2s - loss: 1.4089 - acc: 0.605 - ETA: 2s - loss: 1.4074 - acc: 0.605 - ETA: 2s - loss: 1.4107 - acc: 0.604 - ETA: 1s - loss: 1.4132 - acc: 0.602 - ETA: 1s - loss: 1.4142 - acc: 0.602 - ETA: 1s - loss: 1.4166 - acc: 0.602 - ETA: 1s - loss: 1.4205 - acc: 0.601 - ETA: 1s - loss: 1.4232 - acc: 0.601 - ETA: 1s - loss: 1.4210 - acc: 0.601 - ETA: 1s - loss: 1.4183 - acc: 0.602 - ETA: 1s - loss: 1.4213 - acc: 0.601 - ETA: 1s - loss: 1.4263 - acc: 0.599 - ETA: 1s - loss: 1.4285 - acc: 0.599 - ETA: 1s - loss: 1.4287 - acc: 0.598 - ETA: 1s - loss: 1.4291 - acc: 0.599 - ETA: 1s - loss: 1.4284 - acc: 0.599 - ETA: 1s - loss: 1.4257 - acc: 0.599 - ETA: 1s - loss: 1.4283 - acc: 0.599 - ETA: 1s - loss: 1.4304 - acc: 0.599 - ETA: 1s - loss: 1.4326 - acc: 0.598 - ETA: 1s - loss: 1.4368 - acc: 0.597 - ETA: 0s - loss: 1.4347 - acc: 0.597 - ETA: 0s - loss: 1.4378 - acc: 0.597 - ETA: 0s - loss: 1.4375 - acc: 0.597 - ETA: 0s - loss: 1.4338 - acc: 0.598 - ETA: 0s - loss: 1.4365 - acc: 0.597 - ETA: 0s - loss: 1.4380 - acc: 0.596 - ETA: 0s - loss: 1.4369 - acc: 0.597 - ETA: 0s - loss: 1.4385 - acc: 0.596 - ETA: 0s - loss: 1.4379 - acc: 0.597 - ETA: 0s - loss: 1.4375 - acc: 0.596 - ETA: 0s - loss: 1.4373 - acc: 0.597 - ETA: 0s - loss: 1.4355 - acc: 0.597 - ETA ...
# 6680/6680 [==============================] - 6s - loss: 1.4410 - acc: 0.5966 - val_loss: 2.1358 - val_acc: 0.4802
# Epoch 5/20
# 6620/6680 [============================>.] - ETA: 5s - loss: 1.0009 - acc: 0.650 - ETA: 6s - loss: 0.8921 - acc: 0.737 - ETA: 6s - loss: 0.8606 - acc: 0.750 - ETA: 6s - loss: 0.9101 - acc: 0.735 - ETA: 6s - loss: 0.9682 - acc: 0.719 - ETA: 6s - loss: 0.9762 - acc: 0.703 - ETA: 5s - loss: 1.0210 - acc: 0.692 - ETA: 5s - loss: 1.0003 - acc: 0.700 - ETA: 5s - loss: 1.0650 - acc: 0.694 - ETA: 5s - loss: 1.0381 - acc: 0.700 - ETA: 5s - loss: 1.0252 - acc: 0.703 - ETA: 5s - loss: 1.0229 - acc: 0.703 - ETA: 5s - loss: 1.0131 - acc: 0.698 - ETA: 5s - loss: 1.0165 - acc: 0.698 - ETA: 5s - loss: 1.0193 - acc: 0.695 - ETA: 5s - loss: 1.0316 - acc: 0.692 - ETA: 5s - loss: 1.0243 - acc: 0.691 - ETA: 5s - loss: 1.0219 - acc: 0.693 - ETA: 5s - loss: 1.0174 - acc: 0.695 - ETA: 5s - loss: 1.0072 - acc: 0.694 - ETA: 5s - loss: 1.0050 - acc: 0.697 - ETA: 5s - loss: 1.0059 - acc: 0.696 - ETA: 5s - loss: 1.0103 - acc: 0.696 - ETA: 5s - loss: 0.9964 - acc: 0.697 - ETA: 4s - loss: 0.9874 - acc: 0.700 - ETA: 4s - loss: 1.0028 - acc: 0.698 - ETA: 4s - loss: 1.0162 - acc: 0.695 - ETA: 4s - loss: 1.0271 - acc: 0.695 - ETA: 4s - loss: 1.0310 - acc: 0.696 - ETA: 4s - loss: 1.0337 - acc: 0.696 - ETA: 4s - loss: 1.0391 - acc: 0.696 - ETA: 4s - loss: 1.0457 - acc: 0.695 - ETA: 4s - loss: 1.0412 - acc: 0.695 - ETA: 4s - loss: 1.0446 - acc: 0.694 - ETA: 4s - loss: 1.0455 - acc: 0.693 - ETA: 4s - loss: 1.0556 - acc: 0.690 - ETA: 4s - loss: 1.0605 - acc: 0.688 - ETA: 4s - loss: 1.0617 - acc: 0.689 - ETA: 4s - loss: 1.0604 - acc: 0.688 - ETA: 4s - loss: 1.0690 - acc: 0.684 - ETA: 4s - loss: 1.0737 - acc: 0.683 - ETA: 3s - loss: 1.0743 - acc: 0.683 - ETA: 3s - loss: 1.0837 - acc: 0.678 - ETA: 3s - loss: 1.0882 - acc: 0.676 - ETA: 3s - loss: 1.0873 - acc: 0.679 - ETA: 3s - loss: 1.0899 - acc: 0.677 - ETA: 3s - loss: 1.0927 - acc: 0.678 - ETA: 3s - loss: 1.0896 - acc: 0.679 - ETA: 3s - loss: 1.0925 - acc: 0.679 - ETA: 3s - loss: 1.0901 - acc: 0.680 - ETA: 3s - loss: 1.1007 - acc: 0.678 - ETA: 3s - loss: 1.1075 - acc: 0.677 - ETA: 3s - loss: 1.1081 - acc: 0.676 - ETA: 3s - loss: 1.1040 - acc: 0.676 - ETA: 3s - loss: 1.1076 - acc: 0.675 - ETA: 3s - loss: 1.1070 - acc: 0.675 - ETA: 3s - loss: 1.1029 - acc: 0.676 - ETA: 3s - loss: 1.0987 - acc: 0.677 - ETA: 2s - loss: 1.1040 - acc: 0.676 - ETA: 2s - loss: 1.1018 - acc: 0.676 - ETA: 2s - loss: 1.0999 - acc: 0.676 - ETA: 2s - loss: 1.1015 - acc: 0.676 - ETA: 2s - loss: 1.1044 - acc: 0.676 - ETA: 2s - loss: 1.1035 - acc: 0.676 - ETA: 2s - loss: 1.1001 - acc: 0.676 - ETA: 2s - loss: 1.0980 - acc: 0.676 - ETA: 2s - loss: 1.0975 - acc: 0.675 - ETA: 2s - loss: 1.0976 - acc: 0.675 - ETA: 2s - loss: 1.0954 - acc: 0.676 - ETA: 2s - loss: 1.0985 - acc: 0.675 - ETA: 2s - loss: 1.1035 - acc: 0.673 - ETA: 2s - loss: 1.1053 - acc: 0.673 - ETA: 2s - loss: 1.1131 - acc: 0.671 - ETA: 2s - loss: 1.1103 - acc: 0.673 - ETA: 2s - loss: 1.1097 - acc: 0.673 - ETA: 2s - loss: 1.1119 - acc: 0.673 - ETA: 1s - loss: 1.1124 - acc: 0.672 - ETA: 1s - loss: 1.1093 - acc: 0.674 - ETA: 1s - loss: 1.1119 - acc: 0.673 - ETA: 1s - loss: 1.1106 - acc: 0.673 - ETA: 1s - loss: 1.1100 - acc: 0.673 - ETA: 1s - loss: 1.1099 - acc: 0.673 - ETA: 1s - loss: 1.1094 - acc: 0.673 - ETA: 1s - loss: 1.1065 - acc: 0.674 - ETA: 1s - loss: 1.1103 - acc: 0.673 - ETA: 1s - loss: 1.1090 - acc: 0.672 - ETA: 1s - loss: 1.1083 - acc: 0.673 - ETA: 1s - loss: 1.1102 - acc: 0.672 - ETA: 1s - loss: 1.1073 - acc: 0.673 - ETA: 1s - loss: 1.1054 - acc: 0.673 - ETA: 1s - loss: 1.1063 - acc: 0.673 - ETA: 1s - loss: 1.1038 - acc: 0.674 - ETA: 1s - loss: 1.1051 - acc: 0.673 - ETA: 1s - loss: 1.1066 - acc: 0.673 - ETA: 0s - loss: 1.1058 - acc: 0.673 - ETA: 0s - loss: 1.1057 - acc: 0.673 - ETA: 0s - loss: 1.1034 - acc: 0.674 - ETA: 0s - loss: 1.1031 - acc: 0.674 - ETA: 0s - loss: 1.1035 - acc: 0.674 - ETA: 0s - loss: 1.1035 - acc: 0.675 - ETA: 0s - loss: 1.1074 - acc: 0.674 - ETA: 0s - loss: 1.1034 - acc: 0.675 - ETA: 0s - loss: 1.1005 - acc: 0.675 - ETA: 0s - loss: 1.1024 - acc: 0.675 - ETA ...
# 6680/6680 [==============================] - 6s - loss: 1.1113 - acc: 0.6729 - val_loss: 2.2423 - val_acc: 0.4934
# Epoch 6/20
# 6660/6680 [============================>.] - ETA: 5s - loss: 1.0982 - acc: 0.750 - ETA: 5s - loss: 1.0961 - acc: 0.625 - ETA: 5s - loss: 0.8892 - acc: 0.700 - ETA: 5s - loss: 0.9037 - acc: 0.720 - ETA: 5s - loss: 0.8601 - acc: 0.734 - ETA: 5s - loss: 0.7921 - acc: 0.750 - ETA: 5s - loss: 0.8307 - acc: 0.734 - ETA: 5s - loss: 0.8258 - acc: 0.743 - ETA: 5s - loss: 0.8180 - acc: 0.740 - ETA: 5s - loss: 0.7986 - acc: 0.746 - ETA: 5s - loss: 0.7906 - acc: 0.740 - ETA: 5s - loss: 0.8004 - acc: 0.739 - ETA: 5s - loss: 0.7885 - acc: 0.741 - ETA: 5s - loss: 0.7756 - acc: 0.750 - ETA: 5s - loss: 0.7805 - acc: 0.748 - ETA: 5s - loss: 0.7870 - acc: 0.752 - ETA: 5s - loss: 0.7884 - acc: 0.750 - ETA: 5s - loss: 0.8000 - acc: 0.752 - ETA: 4s - loss: 0.8013 - acc: 0.752 - ETA: 4s - loss: 0.7924 - acc: 0.756 - ETA: 4s - loss: 0.7985 - acc: 0.753 - ETA: 4s - loss: 0.8059 - acc: 0.748 - ETA: 4s - loss: 0.7993 - acc: 0.749 - ETA: 4s - loss: 0.7974 - acc: 0.750 - ETA: 4s - loss: 0.8013 - acc: 0.751 - ETA: 4s - loss: 0.7926 - acc: 0.753 - ETA: 4s - loss: 0.7960 - acc: 0.752 - ETA: 4s - loss: 0.8017 - acc: 0.748 - ETA: 4s - loss: 0.7991 - acc: 0.749 - ETA: 4s - loss: 0.8140 - acc: 0.748 - ETA: 4s - loss: 0.8148 - acc: 0.747 - ETA: 4s - loss: 0.8185 - acc: 0.745 - ETA: 4s - loss: 0.8251 - acc: 0.742 - ETA: 4s - loss: 0.8351 - acc: 0.741 - ETA: 4s - loss: 0.8330 - acc: 0.741 - ETA: 4s - loss: 0.8251 - acc: 0.744 - ETA: 4s - loss: 0.8239 - acc: 0.743 - ETA: 3s - loss: 0.8272 - acc: 0.743 - ETA: 3s - loss: 0.8280 - acc: 0.743 - ETA: 3s - loss: 0.8328 - acc: 0.743 - ETA: 3s - loss: 0.8375 - acc: 0.743 - ETA: 3s - loss: 0.8368 - acc: 0.742 - ETA: 3s - loss: 0.8332 - acc: 0.743 - ETA: 3s - loss: 0.8315 - acc: 0.743 - ETA: 3s - loss: 0.8314 - acc: 0.742 - ETA: 3s - loss: 0.8311 - acc: 0.744 - ETA: 3s - loss: 0.8414 - acc: 0.742 - ETA: 3s - loss: 0.8469 - acc: 0.741 - ETA: 3s - loss: 0.8442 - acc: 0.741 - ETA: 3s - loss: 0.8513 - acc: 0.739 - ETA: 3s - loss: 0.8525 - acc: 0.738 - ETA: 3s - loss: 0.8472 - acc: 0.740 - ETA: 3s - loss: 0.8453 - acc: 0.739 - ETA: 3s - loss: 0.8498 - acc: 0.738 - ETA: 3s - loss: 0.8489 - acc: 0.739 - ETA: 2s - loss: 0.8542 - acc: 0.738 - ETA: 2s - loss: 0.8507 - acc: 0.739 - ETA: 2s - loss: 0.8490 - acc: 0.740 - ETA: 2s - loss: 0.8487 - acc: 0.739 - ETA: 2s - loss: 0.8482 - acc: 0.739 - ETA: 2s - loss: 0.8483 - acc: 0.739 - ETA: 2s - loss: 0.8476 - acc: 0.740 - ETA: 2s - loss: 0.8479 - acc: 0.739 - ETA: 2s - loss: 0.8513 - acc: 0.739 - ETA: 2s - loss: 0.8514 - acc: 0.739 - ETA: 2s - loss: 0.8518 - acc: 0.739 - ETA: 2s - loss: 0.8512 - acc: 0.740 - ETA: 2s - loss: 0.8499 - acc: 0.740 - ETA: 2s - loss: 0.8498 - acc: 0.740 - ETA: 2s - loss: 0.8512 - acc: 0.740 - ETA: 2s - loss: 0.8467 - acc: 0.740 - ETA: 2s - loss: 0.8562 - acc: 0.738 - ETA: 2s - loss: 0.8563 - acc: 0.738 - ETA: 2s - loss: 0.8510 - acc: 0.739 - ETA: 1s - loss: 0.8536 - acc: 0.738 - ETA: 1s - loss: 0.8537 - acc: 0.738 - ETA: 1s - loss: 0.8543 - acc: 0.739 - ETA: 1s - loss: 0.8562 - acc: 0.738 - ETA: 1s - loss: 0.8587 - acc: 0.737 - ETA: 1s - loss: 0.8560 - acc: 0.738 - ETA: 1s - loss: 0.8600 - acc: 0.737 - ETA: 1s - loss: 0.8614 - acc: 0.737 - ETA: 1s - loss: 0.8601 - acc: 0.737 - ETA: 1s - loss: 0.8642 - acc: 0.737 - ETA: 1s - loss: 0.8644 - acc: 0.737 - ETA: 1s - loss: 0.8621 - acc: 0.738 - ETA: 1s - loss: 0.8606 - acc: 0.738 - ETA: 1s - loss: 0.8638 - acc: 0.738 - ETA: 1s - loss: 0.8614 - acc: 0.738 - ETA: 1s - loss: 0.8608 - acc: 0.738 - ETA: 1s - loss: 0.8602 - acc: 0.737 - ETA: 1s - loss: 0.8596 - acc: 0.737 - ETA: 0s - loss: 0.8583 - acc: 0.737 - ETA: 0s - loss: 0.8614 - acc: 0.737 - ETA: 0s - loss: 0.8574 - acc: 0.738 - ETA: 0s - loss: 0.8582 - acc: 0.738 - ETA: 0s - loss: 0.8598 - acc: 0.738 - ETA: 0s - loss: 0.8621 - acc: 0.738 - ETA: 0s - loss: 0.8615 - acc: 0.738 - ETA: 0s - loss: 0.8626 - acc: 0.737 - ETA: 0s - loss: 0.8655 - acc: 0.737 - ETA: 0s - loss: 0.8660 - acc: 0.737 - ETA: 0s - loss: 0.8668 - acc: 0.737 - ETA: 0s - loss: 0.8704 - acc: 0.737 - ETA ...
# 6680/6680 [==============================] - 6s - loss: 0.8842 - acc: 0.7332 - val_loss: 2.1332 - val_acc: 0.5090
# Epoch 7/20
# 6640/6680 [============================>.] - ETA: 6s - loss: 0.7137 - acc: 0.700 - ETA: 5s - loss: 0.5491 - acc: 0.800 - ETA: 6s - loss: 0.5445 - acc: 0.807 - ETA: 5s - loss: 0.5170 - acc: 0.815 - ETA: 5s - loss: 0.5522 - acc: 0.819 - ETA: 5s - loss: 0.5444 - acc: 0.818 - ETA: 5s - loss: 0.5531 - acc: 0.828 - ETA: 5s - loss: 0.5725 - acc: 0.827 - ETA: 5s - loss: 0.6042 - acc: 0.818 - ETA: 5s - loss: 0.6468 - acc: 0.814 - ETA: 5s - loss: 0.6349 - acc: 0.812 - ETA: 5s - loss: 0.6357 - acc: 0.811 - ETA: 5s - loss: 0.6293 - acc: 0.813 - ETA: 5s - loss: 0.6238 - acc: 0.808 - ETA: 5s - loss: 0.6151 - acc: 0.811 - ETA: 5s - loss: 0.6292 - acc: 0.807 - ETA: 5s - loss: 0.6292 - acc: 0.806 - ETA: 5s - loss: 0.6324 - acc: 0.804 - ETA: 5s - loss: 0.6345 - acc: 0.803 - ETA: 5s - loss: 0.6381 - acc: 0.800 - ETA: 5s - loss: 0.6307 - acc: 0.804 - ETA: 4s - loss: 0.6257 - acc: 0.805 - ETA: 4s - loss: 0.6267 - acc: 0.807 - ETA: 4s - loss: 0.6293 - acc: 0.806 - ETA: 4s - loss: 0.6375 - acc: 0.803 - ETA: 4s - loss: 0.6360 - acc: 0.803 - ETA: 4s - loss: 0.6385 - acc: 0.802 - ETA: 4s - loss: 0.6282 - acc: 0.804 - ETA: 4s - loss: 0.6305 - acc: 0.806 - ETA: 4s - loss: 0.6335 - acc: 0.805 - ETA: 4s - loss: 0.6349 - acc: 0.807 - ETA: 4s - loss: 0.6291 - acc: 0.808 - ETA: 4s - loss: 0.6325 - acc: 0.806 - ETA: 4s - loss: 0.6306 - acc: 0.806 - ETA: 4s - loss: 0.6395 - acc: 0.805 - ETA: 4s - loss: 0.6495 - acc: 0.802 - ETA: 4s - loss: 0.6557 - acc: 0.801 - ETA: 3s - loss: 0.6695 - acc: 0.797 - ETA: 3s - loss: 0.6653 - acc: 0.797 - ETA: 3s - loss: 0.6683 - acc: 0.795 - ETA: 3s - loss: 0.6672 - acc: 0.794 - ETA: 3s - loss: 0.6720 - acc: 0.793 - ETA: 3s - loss: 0.6725 - acc: 0.792 - ETA: 3s - loss: 0.6711 - acc: 0.792 - ETA: 3s - loss: 0.6701 - acc: 0.791 - ETA: 3s - loss: 0.6672 - acc: 0.792 - ETA: 3s - loss: 0.6655 - acc: 0.792 - ETA: 3s - loss: 0.6658 - acc: 0.793 - ETA: 3s - loss: 0.6648 - acc: 0.793 - ETA: 3s - loss: 0.6654 - acc: 0.792 - ETA: 3s - loss: 0.6679 - acc: 0.792 - ETA: 3s - loss: 0.6674 - acc: 0.790 - ETA: 3s - loss: 0.6671 - acc: 0.791 - ETA: 3s - loss: 0.6700 - acc: 0.790 - ETA: 3s - loss: 0.6675 - acc: 0.792 - ETA: 2s - loss: 0.6645 - acc: 0.792 - ETA: 2s - loss: 0.6666 - acc: 0.792 - ETA: 2s - loss: 0.6680 - acc: 0.791 - ETA: 2s - loss: 0.6698 - acc: 0.791 - ETA: 2s - loss: 0.6676 - acc: 0.791 - ETA: 2s - loss: 0.6684 - acc: 0.789 - ETA: 2s - loss: 0.6714 - acc: 0.788 - ETA: 2s - loss: 0.6766 - acc: 0.787 - ETA: 2s - loss: 0.6725 - acc: 0.787 - ETA: 2s - loss: 0.6744 - acc: 0.787 - ETA: 2s - loss: 0.6735 - acc: 0.787 - ETA: 2s - loss: 0.6757 - acc: 0.787 - ETA: 2s - loss: 0.6790 - acc: 0.786 - ETA: 2s - loss: 0.6787 - acc: 0.786 - ETA: 2s - loss: 0.6791 - acc: 0.786 - ETA: 2s - loss: 0.6770 - acc: 0.786 - ETA: 2s - loss: 0.6806 - acc: 0.785 - ETA: 2s - loss: 0.6841 - acc: 0.783 - ETA: 1s - loss: 0.6820 - acc: 0.783 - ETA: 1s - loss: 0.6807 - acc: 0.784 - ETA: 1s - loss: 0.6797 - acc: 0.784 - ETA: 1s - loss: 0.6796 - acc: 0.784 - ETA: 1s - loss: 0.6809 - acc: 0.784 - ETA: 1s - loss: 0.6805 - acc: 0.784 - ETA: 1s - loss: 0.6814 - acc: 0.783 - ETA: 1s - loss: 0.6829 - acc: 0.784 - ETA: 1s - loss: 0.6810 - acc: 0.784 - ETA: 1s - loss: 0.6847 - acc: 0.783 - ETA: 1s - loss: 0.6863 - acc: 0.783 - ETA: 1s - loss: 0.6855 - acc: 0.783 - ETA: 1s - loss: 0.6848 - acc: 0.782 - ETA: 1s - loss: 0.6889 - acc: 0.783 - ETA: 1s - loss: 0.6904 - acc: 0.782 - ETA: 1s - loss: 0.6891 - acc: 0.783 - ETA: 1s - loss: 0.6876 - acc: 0.782 - ETA: 0s - loss: 0.6865 - acc: 0.783 - ETA: 0s - loss: 0.6896 - acc: 0.781 - ETA: 0s - loss: 0.6910 - acc: 0.782 - ETA: 0s - loss: 0.6905 - acc: 0.782 - ETA: 0s - loss: 0.6923 - acc: 0.782 - ETA: 0s - loss: 0.6910 - acc: 0.782 - ETA: 0s - loss: 0.6910 - acc: 0.782 - ETA: 0s - loss: 0.6893 - acc: 0.783 - ETA: 0s - loss: 0.6901 - acc: 0.783 - ETA: 0s - loss: 0.6912 - acc: 0.782 - ETA: 0s - loss: 0.6947 - acc: 0.781 - ETA: 0s - loss: 0.6968 - acc: 0.780 - ETA: 0s - loss: 0.6975 - acc: 0.780 - ETA: 0s - loss: 0.6974 - acc: 0.780 - ETA ...
# 6680/6680 [==============================] - 6s - loss: 0.7137 - acc: 0.7774 - val_loss: 2.2005 - val_acc: 0.5413
# Epoch 8/20
# 6640/6680 [============================>.] - ETA: 6s - loss: 0.7476 - acc: 0.700 - ETA: 6s - loss: 0.5083 - acc: 0.812 - ETA: 6s - loss: 0.4357 - acc: 0.842 - ETA: 6s - loss: 0.4608 - acc: 0.840 - ETA: 6s - loss: 0.4424 - acc: 0.838 - ETA: 6s - loss: 0.4313 - acc: 0.850 - ETA: 6s - loss: 0.4298 - acc: 0.850 - ETA: 6s - loss: 0.4391 - acc: 0.854 - ETA: 5s - loss: 0.4366 - acc: 0.850 - ETA: 5s - loss: 0.4527 - acc: 0.837 - ETA: 5s - loss: 0.4965 - acc: 0.835 - ETA: 5s - loss: 0.5038 - acc: 0.830 - ETA: 5s - loss: 0.5122 - acc: 0.829 - ETA: 5s - loss: 0.5067 - acc: 0.832 - ETA: 5s - loss: 0.5076 - acc: 0.827 - ETA: 5s - loss: 0.5247 - acc: 0.821 - ETA: 5s - loss: 0.5434 - acc: 0.814 - ETA: 5s - loss: 0.5327 - acc: 0.818 - ETA: 5s - loss: 0.5404 - acc: 0.817 - ETA: 5s - loss: 0.5431 - acc: 0.817 - ETA: 5s - loss: 0.5430 - acc: 0.815 - ETA: 5s - loss: 0.5319 - acc: 0.820 - ETA: 5s - loss: 0.5379 - acc: 0.817 - ETA: 5s - loss: 0.5352 - acc: 0.817 - ETA: 5s - loss: 0.5467 - acc: 0.815 - ETA: 5s - loss: 0.5499 - acc: 0.815 - ETA: 5s - loss: 0.5531 - acc: 0.817 - ETA: 4s - loss: 0.5432 - acc: 0.820 - ETA: 4s - loss: 0.5420 - acc: 0.819 - ETA: 4s - loss: 0.5438 - acc: 0.819 - ETA: 4s - loss: 0.5603 - acc: 0.817 - ETA: 4s - loss: 0.5626 - acc: 0.815 - ETA: 4s - loss: 0.5633 - acc: 0.814 - ETA: 4s - loss: 0.5697 - acc: 0.811 - ETA: 4s - loss: 0.5735 - acc: 0.809 - ETA: 4s - loss: 0.5717 - acc: 0.810 - ETA: 4s - loss: 0.5752 - acc: 0.809 - ETA: 4s - loss: 0.5773 - acc: 0.808 - ETA: 4s - loss: 0.5727 - acc: 0.810 - ETA: 4s - loss: 0.5718 - acc: 0.811 - ETA: 4s - loss: 0.5678 - acc: 0.812 - ETA: 4s - loss: 0.5660 - acc: 0.814 - ETA: 4s - loss: 0.5730 - acc: 0.813 - ETA: 4s - loss: 0.5712 - acc: 0.812 - ETA: 3s - loss: 0.5729 - acc: 0.812 - ETA: 3s - loss: 0.5683 - acc: 0.813 - ETA: 3s - loss: 0.5676 - acc: 0.813 - ETA: 3s - loss: 0.5626 - acc: 0.814 - ETA: 3s - loss: 0.5657 - acc: 0.814 - ETA: 3s - loss: 0.5622 - acc: 0.815 - ETA: 3s - loss: 0.5619 - acc: 0.814 - ETA: 3s - loss: 0.5642 - acc: 0.814 - ETA: 3s - loss: 0.5728 - acc: 0.812 - ETA: 3s - loss: 0.5743 - acc: 0.811 - ETA: 3s - loss: 0.5708 - acc: 0.812 - ETA: 3s - loss: 0.5688 - acc: 0.812 - ETA: 3s - loss: 0.5692 - acc: 0.812 - ETA: 3s - loss: 0.5690 - acc: 0.812 - ETA: 3s - loss: 0.5671 - acc: 0.813 - ETA: 3s - loss: 0.5686 - acc: 0.813 - ETA: 3s - loss: 0.5662 - acc: 0.814 - ETA: 3s - loss: 0.5678 - acc: 0.813 - ETA: 2s - loss: 0.5654 - acc: 0.813 - ETA: 2s - loss: 0.5724 - acc: 0.812 - ETA: 2s - loss: 0.5744 - acc: 0.813 - ETA: 2s - loss: 0.5746 - acc: 0.813 - ETA: 2s - loss: 0.5757 - acc: 0.813 - ETA: 2s - loss: 0.5761 - acc: 0.813 - ETA: 2s - loss: 0.5760 - acc: 0.813 - ETA: 2s - loss: 0.5759 - acc: 0.812 - ETA: 2s - loss: 0.5770 - acc: 0.811 - ETA: 2s - loss: 0.5775 - acc: 0.811 - ETA: 2s - loss: 0.5754 - acc: 0.812 - ETA: 2s - loss: 0.5740 - acc: 0.812 - ETA: 2s - loss: 0.5743 - acc: 0.812 - ETA: 2s - loss: 0.5704 - acc: 0.813 - ETA: 2s - loss: 0.5688 - acc: 0.814 - ETA: 2s - loss: 0.5692 - acc: 0.813 - ETA: 2s - loss: 0.5716 - acc: 0.812 - ETA: 1s - loss: 0.5753 - acc: 0.811 - ETA: 1s - loss: 0.5760 - acc: 0.812 - ETA: 1s - loss: 0.5723 - acc: 0.813 - ETA: 1s - loss: 0.5716 - acc: 0.812 - ETA: 1s - loss: 0.5750 - acc: 0.812 - ETA: 1s - loss: 0.5785 - acc: 0.811 - ETA: 1s - loss: 0.5790 - acc: 0.810 - ETA: 1s - loss: 0.5811 - acc: 0.810 - ETA: 1s - loss: 0.5847 - acc: 0.810 - ETA: 1s - loss: 0.5869 - acc: 0.810 - ETA: 1s - loss: 0.5872 - acc: 0.810 - ETA: 1s - loss: 0.5899 - acc: 0.809 - ETA: 1s - loss: 0.5878 - acc: 0.810 - ETA: 1s - loss: 0.5871 - acc: 0.810 - ETA: 1s - loss: 0.5868 - acc: 0.810 - ETA: 1s - loss: 0.5870 - acc: 0.810 - ETA: 0s - loss: 0.5891 - acc: 0.811 - ETA: 0s - loss: 0.5874 - acc: 0.811 - ETA: 0s - loss: 0.5861 - acc: 0.811 - ETA: 0s - loss: 0.5882 - acc: 0.811 - ETA: 0s - loss: 0.5911 - acc: 0.811 - ETA: 0s - loss: 0.5925 - acc: 0.810 - ETA: 0s - loss: 0.5943 - acc: 0.810 - ETA: 0s - loss: 0.5937 - acc: 0.810 - ETA: 0s - loss: 0.5937 - acc: 0.810 - ETA ...
# 6680/6680 [==============================] - 6s - loss: 0.5981 - acc: 0.8106 - val_loss: 2.3770 - val_acc: 0.5389
# Epoch 9/20
# 6640/6680 [============================>.] - ETA: 6s - loss: 0.5288 - acc: 0.750 - ETA: 5s - loss: 0.4168 - acc: 0.812 - ETA: 6s - loss: 0.3876 - acc: 0.850 - ETA: 6s - loss: 0.4066 - acc: 0.850 - ETA: 6s - loss: 0.4073 - acc: 0.850 - ETA: 6s - loss: 0.4180 - acc: 0.840 - ETA: 6s - loss: 0.4000 - acc: 0.852 - ETA: 6s - loss: 0.4242 - acc: 0.854 - ETA: 6s - loss: 0.4213 - acc: 0.854 - ETA: 5s - loss: 0.3937 - acc: 0.866 - ETA: 6s - loss: 0.3874 - acc: 0.863 - ETA: 6s - loss: 0.3931 - acc: 0.860 - ETA: 5s - loss: 0.3962 - acc: 0.862 - ETA: 5s - loss: 0.3983 - acc: 0.860 - ETA: 5s - loss: 0.4172 - acc: 0.854 - ETA: 5s - loss: 0.4068 - acc: 0.860 - ETA: 5s - loss: 0.4140 - acc: 0.861 - ETA: 5s - loss: 0.4309 - acc: 0.854 - ETA: 5s - loss: 0.4166 - acc: 0.860 - ETA: 5s - loss: 0.4329 - acc: 0.857 - ETA: 5s - loss: 0.4310 - acc: 0.860 - ETA: 5s - loss: 0.4301 - acc: 0.858 - ETA: 5s - loss: 0.4367 - acc: 0.856 - ETA: 5s - loss: 0.4311 - acc: 0.859 - ETA: 5s - loss: 0.4310 - acc: 0.858 - ETA: 5s - loss: 0.4390 - acc: 0.856 - ETA: 5s - loss: 0.4375 - acc: 0.855 - ETA: 5s - loss: 0.4449 - acc: 0.853 - ETA: 5s - loss: 0.4386 - acc: 0.856 - ETA: 4s - loss: 0.4326 - acc: 0.857 - ETA: 4s - loss: 0.4304 - acc: 0.857 - ETA: 4s - loss: 0.4264 - acc: 0.859 - ETA: 4s - loss: 0.4224 - acc: 0.860 - ETA: 4s - loss: 0.4279 - acc: 0.858 - ETA: 4s - loss: 0.4375 - acc: 0.853 - ETA: 4s - loss: 0.4380 - acc: 0.854 - ETA: 4s - loss: 0.4332 - acc: 0.856 - ETA: 4s - loss: 0.4337 - acc: 0.855 - ETA: 4s - loss: 0.4352 - acc: 0.855 - ETA: 4s - loss: 0.4372 - acc: 0.855 - ETA: 4s - loss: 0.4382 - acc: 0.854 - ETA: 4s - loss: 0.4453 - acc: 0.852 - ETA: 4s - loss: 0.4398 - acc: 0.854 - ETA: 4s - loss: 0.4446 - acc: 0.853 - ETA: 4s - loss: 0.4455 - acc: 0.852 - ETA: 4s - loss: 0.4527 - acc: 0.850 - ETA: 4s - loss: 0.4542 - acc: 0.849 - ETA: 4s - loss: 0.4573 - acc: 0.847 - ETA: 3s - loss: 0.4558 - acc: 0.847 - ETA: 3s - loss: 0.4576 - acc: 0.847 - ETA: 3s - loss: 0.4588 - acc: 0.846 - ETA: 3s - loss: 0.4613 - acc: 0.844 - ETA: 3s - loss: 0.4591 - acc: 0.845 - ETA: 3s - loss: 0.4586 - acc: 0.845 - ETA: 3s - loss: 0.4578 - acc: 0.846 - ETA: 3s - loss: 0.4547 - acc: 0.847 - ETA: 3s - loss: 0.4527 - acc: 0.848 - ETA: 3s - loss: 0.4587 - acc: 0.847 - ETA: 3s - loss: 0.4601 - acc: 0.847 - ETA: 3s - loss: 0.4589 - acc: 0.847 - ETA: 3s - loss: 0.4562 - acc: 0.848 - ETA: 3s - loss: 0.4558 - acc: 0.848 - ETA: 3s - loss: 0.4608 - acc: 0.846 - ETA: 3s - loss: 0.4620 - acc: 0.847 - ETA: 3s - loss: 0.4618 - acc: 0.848 - ETA: 3s - loss: 0.4634 - acc: 0.846 - ETA: 2s - loss: 0.4635 - acc: 0.846 - ETA: 2s - loss: 0.4629 - acc: 0.846 - ETA: 2s - loss: 0.4605 - acc: 0.847 - ETA: 2s - loss: 0.4582 - acc: 0.847 - ETA: 2s - loss: 0.4586 - acc: 0.847 - ETA: 2s - loss: 0.4606 - acc: 0.846 - ETA: 2s - loss: 0.4658 - acc: 0.846 - ETA: 2s - loss: 0.4636 - acc: 0.846 - ETA: 2s - loss: 0.4660 - acc: 0.846 - ETA: 2s - loss: 0.4699 - acc: 0.845 - ETA: 2s - loss: 0.4689 - acc: 0.846 - ETA: 2s - loss: 0.4693 - acc: 0.846 - ETA: 2s - loss: 0.4750 - acc: 0.844 - ETA: 2s - loss: 0.4740 - acc: 0.844 - ETA: 2s - loss: 0.4787 - acc: 0.842 - ETA: 1s - loss: 0.4793 - acc: 0.842 - ETA: 1s - loss: 0.4787 - acc: 0.842 - ETA: 1s - loss: 0.4792 - acc: 0.843 - ETA: 1s - loss: 0.4779 - acc: 0.843 - ETA: 1s - loss: 0.4820 - acc: 0.843 - ETA: 1s - loss: 0.4808 - acc: 0.842 - ETA: 1s - loss: 0.4798 - acc: 0.843 - ETA: 1s - loss: 0.4828 - acc: 0.843 - ETA: 1s - loss: 0.4833 - acc: 0.843 - ETA: 1s - loss: 0.4859 - acc: 0.841 - ETA: 1s - loss: 0.4870 - acc: 0.841 - ETA: 1s - loss: 0.4878 - acc: 0.841 - ETA: 1s - loss: 0.4878 - acc: 0.841 - ETA: 1s - loss: 0.4867 - acc: 0.841 - ETA: 1s - loss: 0.4861 - acc: 0.842 - ETA: 1s - loss: 0.4875 - acc: 0.841 - ETA: 0s - loss: 0.4841 - acc: 0.842 - ETA: 0s - loss: 0.4846 - acc: 0.842 - ETA: 0s - loss: 0.4826 - acc: 0.843 - ETA: 0s - loss: 0.4831 - acc: 0.843 - ETA: 0s - loss: 0.4834 - acc: 0.842 - ETA: 0s - loss: 0.4868 - acc: 0.841 - ETA: 0s - loss: 0.4864 - acc: 0.841 - ETA ...
# 6680/6680 [==============================] - 6s - loss: 0.4917 - acc: 0.8409 - val_loss: 2.4557 - val_acc: 0.5401
# Epoch 10/20
# 6620/6680 [============================>.] - ETA: 5s - loss: 1.0086 - acc: 0.850 - ETA: 5s - loss: 0.4151 - acc: 0.900 - ETA: 5s - loss: 0.3750 - acc: 0.885 - ETA: 5s - loss: 0.3339 - acc: 0.880 - ETA: 5s - loss: 0.3668 - acc: 0.892 - ETA: 5s - loss: 0.3522 - acc: 0.890 - ETA: 5s - loss: 0.3400 - acc: 0.886 - ETA: 5s - loss: 0.3913 - acc: 0.875 - ETA: 5s - loss: 0.3876 - acc: 0.870 - ETA: 5s - loss: 0.3878 - acc: 0.871 - ETA: 5s - loss: 0.3606 - acc: 0.882 - ETA: 5s - loss: 0.3545 - acc: 0.882 - ETA: 5s - loss: 0.3459 - acc: 0.885 - ETA: 5s - loss: 0.3415 - acc: 0.889 - ETA: 5s - loss: 0.3384 - acc: 0.889 - ETA: 5s - loss: 0.3521 - acc: 0.888 - ETA: 4s - loss: 0.3484 - acc: 0.890 - ETA: 4s - loss: 0.3506 - acc: 0.888 - ETA: 4s - loss: 0.3737 - acc: 0.882 - ETA: 4s - loss: 0.3722 - acc: 0.883 - ETA: 4s - loss: 0.3647 - acc: 0.883 - ETA: 4s - loss: 0.3667 - acc: 0.883 - ETA: 4s - loss: 0.3607 - acc: 0.884 - ETA: 4s - loss: 0.3555 - acc: 0.886 - ETA: 4s - loss: 0.3566 - acc: 0.884 - ETA: 4s - loss: 0.3564 - acc: 0.884 - ETA: 4s - loss: 0.3491 - acc: 0.887 - ETA: 4s - loss: 0.3490 - acc: 0.888 - ETA: 4s - loss: 0.3472 - acc: 0.887 - ETA: 4s - loss: 0.3427 - acc: 0.889 - ETA: 4s - loss: 0.3392 - acc: 0.891 - ETA: 4s - loss: 0.3392 - acc: 0.890 - ETA: 4s - loss: 0.3474 - acc: 0.889 - ETA: 4s - loss: 0.3502 - acc: 0.889 - ETA: 3s - loss: 0.3500 - acc: 0.888 - ETA: 3s - loss: 0.3510 - acc: 0.887 - ETA: 3s - loss: 0.3529 - acc: 0.885 - ETA: 3s - loss: 0.3491 - acc: 0.886 - ETA: 3s - loss: 0.3527 - acc: 0.885 - ETA: 3s - loss: 0.3563 - acc: 0.883 - ETA: 3s - loss: 0.3588 - acc: 0.882 - ETA: 3s - loss: 0.3638 - acc: 0.881 - ETA: 3s - loss: 0.3637 - acc: 0.880 - ETA: 3s - loss: 0.3652 - acc: 0.879 - ETA: 3s - loss: 0.3707 - acc: 0.877 - ETA: 3s - loss: 0.3706 - acc: 0.878 - ETA: 3s - loss: 0.3725 - acc: 0.877 - ETA: 3s - loss: 0.3773 - acc: 0.876 - ETA: 3s - loss: 0.3823 - acc: 0.874 - ETA: 3s - loss: 0.3846 - acc: 0.873 - ETA: 3s - loss: 0.3848 - acc: 0.873 - ETA: 2s - loss: 0.3910 - acc: 0.871 - ETA: 2s - loss: 0.3941 - acc: 0.870 - ETA: 2s - loss: 0.3943 - acc: 0.870 - ETA: 2s - loss: 0.3937 - acc: 0.869 - ETA: 2s - loss: 0.3911 - acc: 0.870 - ETA: 2s - loss: 0.3891 - acc: 0.872 - ETA: 2s - loss: 0.3878 - acc: 0.873 - ETA: 2s - loss: 0.3838 - acc: 0.874 - ETA: 2s - loss: 0.3832 - acc: 0.874 - ETA: 2s - loss: 0.3816 - acc: 0.875 - ETA: 2s - loss: 0.3809 - acc: 0.875 - ETA: 2s - loss: 0.3844 - acc: 0.875 - ETA: 2s - loss: 0.3847 - acc: 0.875 - ETA: 2s - loss: 0.3837 - acc: 0.874 - ETA: 2s - loss: 0.3888 - acc: 0.873 - ETA: 2s - loss: 0.3886 - acc: 0.873 - ETA: 2s - loss: 0.3869 - acc: 0.873 - ETA: 2s - loss: 0.3851 - acc: 0.873 - ETA: 1s - loss: 0.3843 - acc: 0.874 - ETA: 1s - loss: 0.3908 - acc: 0.871 - ETA: 1s - loss: 0.3904 - acc: 0.871 - ETA: 1s - loss: 0.3906 - acc: 0.871 - ETA: 1s - loss: 0.3930 - acc: 0.871 - ETA: 1s - loss: 0.3936 - acc: 0.870 - ETA: 1s - loss: 0.3932 - acc: 0.870 - ETA: 1s - loss: 0.3937 - acc: 0.870 - ETA: 1s - loss: 0.3916 - acc: 0.870 - ETA: 1s - loss: 0.3972 - acc: 0.869 - ETA: 1s - loss: 0.3967 - acc: 0.869 - ETA: 1s - loss: 0.3977 - acc: 0.869 - ETA: 1s - loss: 0.3977 - acc: 0.869 - ETA: 1s - loss: 0.3959 - acc: 0.870 - ETA: 1s - loss: 0.3964 - acc: 0.870 - ETA: 1s - loss: 0.3980 - acc: 0.869 - ETA: 0s - loss: 0.3995 - acc: 0.869 - ETA: 0s - loss: 0.4027 - acc: 0.868 - ETA: 0s - loss: 0.4044 - acc: 0.868 - ETA: 0s - loss: 0.4038 - acc: 0.868 - ETA: 0s - loss: 0.4035 - acc: 0.867 - ETA: 0s - loss: 0.4064 - acc: 0.867 - ETA: 0s - loss: 0.4048 - acc: 0.868 - ETA: 0s - loss: 0.4045 - acc: 0.868 - ETA: 0s - loss: 0.4058 - acc: 0.867 - ETA: 0s - loss: 0.4070 - acc: 0.866 - ETA: 0s - loss: 0.4057 - acc: 0.867 - ETA: 0s - loss: 0.4088 - acc: 0.865 - ETA: 0s - loss: 0.4115 - acc: 0.864 - ETA: 0s - loss: 0.4126 - acc: 0.864 - ETA: 0s - loss: 0.4133 - acc: 0.864 - ETA: 0s - loss: 0.4195 - acc: 0.863 - ETA: 0s - loss: 0.4195 - acc: 0.863 - ETA: 0s - loss: 0.4196 - acc: 0.8634Epoch 00009: val_loss did not improve
# 6680/6680 [==============================] - 5s - loss: 0.4192 - acc: 0.8635 - val_loss: 2.3013 - val_acc: 0.5665
# Epoch 11/20
# 6640/6680 [============================>.] - ETA: 4s - loss: 0.3225 - acc: 0.900 - ETA: 5s - loss: 0.3034 - acc: 0.910 - ETA: 5s - loss: 0.3061 - acc: 0.881 - ETA: 5s - loss: 0.3570 - acc: 0.877 - ETA: 5s - loss: 0.3318 - acc: 0.885 - ETA: 5s - loss: 0.3622 - acc: 0.882 - ETA: 5s - loss: 0.3485 - acc: 0.887 - ETA: 5s - loss: 0.3527 - acc: 0.884 - ETA: 5s - loss: 0.3516 - acc: 0.880 - ETA: 5s - loss: 0.3402 - acc: 0.889 - ETA: 5s - loss: 0.3249 - acc: 0.898 - ETA: 5s - loss: 0.3137 - acc: 0.900 - ETA: 5s - loss: 0.2997 - acc: 0.905 - ETA: 5s - loss: 0.2957 - acc: 0.907 - ETA: 4s - loss: 0.2978 - acc: 0.907 - ETA: 4s - loss: 0.3028 - acc: 0.903 - ETA: 4s - loss: 0.3001 - acc: 0.904 - ETA: 4s - loss: 0.2978 - acc: 0.907 - ETA: 4s - loss: 0.2991 - acc: 0.906 - ETA: 4s - loss: 0.3056 - acc: 0.905 - ETA: 4s - loss: 0.3024 - acc: 0.904 - ETA: 4s - loss: 0.3095 - acc: 0.902 - ETA: 4s - loss: 0.3046 - acc: 0.903 - ETA: 4s - loss: 0.3019 - acc: 0.904 - ETA: 4s - loss: 0.3036 - acc: 0.904 - ETA: 4s - loss: 0.3100 - acc: 0.901 - ETA: 4s - loss: 0.3056 - acc: 0.901 - ETA: 4s - loss: 0.3084 - acc: 0.898 - ETA: 4s - loss: 0.3070 - acc: 0.897 - ETA: 4s - loss: 0.3058 - acc: 0.896 - ETA: 4s - loss: 0.3035 - acc: 0.897 - ETA: 4s - loss: 0.3079 - acc: 0.896 - ETA: 4s - loss: 0.3075 - acc: 0.895 - ETA: 4s - loss: 0.3042 - acc: 0.897 - ETA: 4s - loss: 0.3074 - acc: 0.896 - ETA: 4s - loss: 0.3126 - acc: 0.894 - ETA: 4s - loss: 0.3119 - acc: 0.894 - ETA: 3s - loss: 0.3112 - acc: 0.894 - ETA: 3s - loss: 0.3130 - acc: 0.893 - ETA: 3s - loss: 0.3075 - acc: 0.895 - ETA: 3s - loss: 0.3113 - acc: 0.894 - ETA: 3s - loss: 0.3117 - acc: 0.895 - ETA: 3s - loss: 0.3088 - acc: 0.896 - ETA: 3s - loss: 0.3072 - acc: 0.896 - ETA: 3s - loss: 0.3053 - acc: 0.897 - ETA: 3s - loss: 0.3074 - acc: 0.896 - ETA: 3s - loss: 0.3070 - acc: 0.896 - ETA: 3s - loss: 0.3128 - acc: 0.895 - ETA: 3s - loss: 0.3120 - acc: 0.895 - ETA: 3s - loss: 0.3080 - acc: 0.897 - ETA: 3s - loss: 0.3083 - acc: 0.896 - ETA: 3s - loss: 0.3158 - acc: 0.894 - ETA: 3s - loss: 0.3195 - acc: 0.895 - ETA: 3s - loss: 0.3218 - acc: 0.894 - ETA: 2s - loss: 0.3197 - acc: 0.894 - ETA: 2s - loss: 0.3213 - acc: 0.894 - ETA: 2s - loss: 0.3187 - acc: 0.894 - ETA: 2s - loss: 0.3169 - acc: 0.895 - ETA: 2s - loss: 0.3166 - acc: 0.895 - ETA: 2s - loss: 0.3170 - acc: 0.894 - ETA: 2s - loss: 0.3184 - acc: 0.894 - ETA: 2s - loss: 0.3217 - acc: 0.893 - ETA: 2s - loss: 0.3206 - acc: 0.893 - ETA: 2s - loss: 0.3201 - acc: 0.893 - ETA: 2s - loss: 0.3196 - acc: 0.893 - ETA: 2s - loss: 0.3203 - acc: 0.892 - ETA: 2s - loss: 0.3213 - acc: 0.892 - ETA: 2s - loss: 0.3196 - acc: 0.893 - ETA: 2s - loss: 0.3195 - acc: 0.894 - ETA: 2s - loss: 0.3222 - acc: 0.894 - ETA: 2s - loss: 0.3213 - acc: 0.894 - ETA: 2s - loss: 0.3211 - acc: 0.894 - ETA: 2s - loss: 0.3221 - acc: 0.894 - ETA: 1s - loss: 0.3266 - acc: 0.893 - ETA: 1s - loss: 0.3268 - acc: 0.893 - ETA: 1s - loss: 0.3260 - acc: 0.893 - ETA: 1s - loss: 0.3240 - acc: 0.894 - ETA: 1s - loss: 0.3274 - acc: 0.893 - ETA: 1s - loss: 0.3271 - acc: 0.893 - ETA: 1s - loss: 0.3283 - acc: 0.892 - ETA: 1s - loss: 0.3278 - acc: 0.893 - ETA: 1s - loss: 0.3274 - acc: 0.893 - ETA: 1s - loss: 0.3263 - acc: 0.893 - ETA: 1s - loss: 0.3291 - acc: 0.893 - ETA: 1s - loss: 0.3287 - acc: 0.893 - ETA: 1s - loss: 0.3260 - acc: 0.894 - ETA: 1s - loss: 0.3263 - acc: 0.894 - ETA: 1s - loss: 0.3325 - acc: 0.893 - ETA: 1s - loss: 0.3309 - acc: 0.894 - ETA: 1s - loss: 0.3290 - acc: 0.894 - ETA: 1s - loss: 0.3291 - acc: 0.894 - ETA: 1s - loss: 0.3269 - acc: 0.895 - ETA: 0s - loss: 0.3293 - acc: 0.894 - ETA: 0s - loss: 0.3307 - acc: 0.894 - ETA: 0s - loss: 0.3317 - acc: 0.894 - ETA: 0s - loss: 0.3340 - acc: 0.893 - ETA: 0s - loss: 0.3343 - acc: 0.893 - ETA: 0s - loss: 0.3333 - acc: 0.892 - ETA: 0s - loss: 0.3352 - acc: 0.892 - ETA: 0s - loss: 0.3339 - acc: 0.892 - ETA: 0s - loss: 0.3370 - acc: 0.892 - ETA: 0s - loss: 0.3357 - acc: 0.892 - ETA: 0s - loss: 0.3366 - acc: 0.891 - ETA: 0s - loss: 0.3371 - acc: 0.891 - ETA ...
# 6680/6680 [==============================] - 6s - loss: 0.3418 - acc: 0.8898 - val_loss: 2.3643 - val_acc: 0.5832
# Epoch 12/20
# ...
# 6680/6680 [==============================] - 5s - loss: 0.1899 - acc: 0.9380 - val_loss: 2.7466 - val_acc: 0.5629
# Epoch 16/20
# 6620/6680 [============================>.] - ETA: 4s - loss: 0.0985 - acc: 0.950 - ETA: 3s - loss: 0.0889 - acc: 0.950 - ETA: 3s - loss: 0.0975 - acc: 0.955 - ETA: 3s - loss: 0.0933 - acc: 0.957 - ETA: 3s - loss: 0.0933 - acc: 0.963 - ETA: 3s - loss: 0.0940 - acc: 0.966 - ETA: 3s - loss: 0.0910 - acc: 0.969 - ETA: 3s - loss: 0.0963 - acc: 0.968 - ETA: 3s - loss: 0.0943 - acc: 0.968 - ETA: 3s - loss: 0.1015 - acc: 0.963 - ETA: 3s - loss: 0.1023 - acc: 0.962 - ETA: 3s - loss: 0.0985 - acc: 0.965 - ETA: 3s - loss: 0.1021 - acc: 0.965 - ETA: 3s - loss: 0.1005 - acc: 0.966 - ETA: 3s - loss: 0.0985 - acc: 0.968 - ETA: 3s - loss: 0.1090 - acc: 0.965 - ETA: 3s - loss: 0.1123 - acc: 0.964 - ETA: 3s - loss: 0.1126 - acc: 0.964 - ETA: 3s - loss: 0.1119 - acc: 0.965 - ETA: 3s - loss: 0.1136 - acc: 0.964 - ETA: 3s - loss: 0.1150 - acc: 0.963 - ETA: 2s - loss: 0.1181 - acc: 0.962 - ETA: 2s - loss: 0.1202 - acc: 0.961 - ETA: 2s - loss: 0.1190 - acc: 0.962 - ETA: 2s - loss: 0.1264 - acc: 0.958 - ETA: 2s - loss: 0.1270 - acc: 0.958 - ETA: 2s - loss: 0.1262 - acc: 0.958 - ETA: 2s - loss: 0.1264 - acc: 0.957 - ETA: 2s - loss: 0.1275 - acc: 0.957 - ETA: 2s - loss: 0.1282 - acc: 0.956 - ETA: 2s - loss: 0.1297 - acc: 0.955 - ETA: 2s - loss: 0.1368 - acc: 0.954 - ETA: 2s - loss: 0.1368 - acc: 0.954 - ETA: 2s - loss: 0.1341 - acc: 0.956 - ETA: 2s - loss: 0.1322 - acc: 0.956 - ETA: 2s - loss: 0.1308 - acc: 0.957 - ETA: 2s - loss: 0.1303 - acc: 0.957 - ETA: 2s - loss: 0.1307 - acc: 0.957 - ETA: 1s - loss: 0.1312 - acc: 0.956 - ETA: 1s - loss: 0.1328 - acc: 0.956 - ETA: 1s - loss: 0.1349 - acc: 0.955 - ETA: 1s - loss: 0.1360 - acc: 0.954 - ETA: 1s - loss: 0.1375 - acc: 0.953 - ETA: 1s - loss: 0.1382 - acc: 0.952 - ETA: 1s - loss: 0.1378 - acc: 0.952 - ETA: 1s - loss: 0.1393 - acc: 0.952 - ETA: 1s - loss: 0.1401 - acc: 0.951 - ETA: 1s - loss: 0.1404 - acc: 0.951 - ETA: 1s - loss: 0.1412 - acc: 0.950 - ETA: 1s - loss: 0.1436 - acc: 0.950 - ETA: 1s - loss: 0.1434 - acc: 0.950 - ETA: 1s - loss: 0.1463 - acc: 0.949 - ETA: 1s - loss: 0.1472 - acc: 0.948 - ETA: 1s - loss: 0.1469 - acc: 0.949 - ETA: 1s - loss: 0.1463 - acc: 0.949 - ETA: 1s - loss: 0.1483 - acc: 0.948 - ETA: 0s - loss: 0.1501 - acc: 0.947 - ETA: 0s - loss: 0.1519 - acc: 0.947 - ETA: 0s - loss: 0.1523 - acc: 0.947 - ETA: 0s - loss: 0.1530 - acc: 0.947 - ETA: 0s - loss: 0.1543 - acc: 0.947 - ETA: 0s - loss: 0.1528 - acc: 0.948 - ETA: 0s - loss: 0.1564 - acc: 0.946 - ETA: 0s - loss: 0.1560 - acc: 0.947 - ETA: 0s - loss: 0.1555 - acc: 0.947 - ETA: 0s - loss: 0.1552 - acc: 0.947 - ETA: 0s - loss: 0.1554 - acc: 0.947 - ETA: 0s - loss: 0.1554 - acc: 0.946 - ETA: 0s - loss: 0.1562 - acc: 0.946 - ETA: 0s - loss: 0.1556 - acc: 0.946 - ETA: 0s - loss: 0.1548 - acc: 0.946 - ETA: 0s - loss: 0.1570 - acc: 0.946 - ETA: 0s - loss: 0.1583 - acc: 0.9467Epoch 00015: val_loss did not improve
# 6680/6680 [==============================] - 4s - loss: 0.1583 - acc: 0.9467 - val_loss: 2.8393 - val_acc: 0.5749
# Epoch 17/20
# 6620/6680 [============================>.] - ETA: 3s - loss: 0.0405 - acc: 1.000 - ETA: 3s - loss: 0.0674 - acc: 0.975 - ETA: 3s - loss: 0.0829 - acc: 0.959 - ETA: 3s - loss: 0.1080 - acc: 0.956 - ETA: 3s - loss: 0.1254 - acc: 0.950 - ETA: 3s - loss: 0.1241 - acc: 0.954 - ETA: 3s - loss: 0.1557 - acc: 0.948 - ETA: 3s - loss: 0.1412 - acc: 0.954 - ETA: 3s - loss: 0.1368 - acc: 0.953 - ETA: 3s - loss: 0.1409 - acc: 0.950 - ETA: 3s - loss: 0.1390 - acc: 0.951 - ETA: 3s - loss: 0.1355 - acc: 0.952 - ETA: 3s - loss: 0.1479 - acc: 0.951 - ETA: 3s - loss: 0.1425 - acc: 0.954 - ETA: 3s - loss: 0.1343 - acc: 0.957 - ETA: 3s - loss: 0.1433 - acc: 0.956 - ETA: 3s - loss: 0.1461 - acc: 0.953 - ETA: 3s - loss: 0.1438 - acc: 0.955 - ETA: 2s - loss: 0.1417 - acc: 0.956 - ETA: 2s - loss: 0.1383 - acc: 0.956 - ETA: 2s - loss: 0.1346 - acc: 0.958 - ETA: 2s - loss: 0.1319 - acc: 0.959 - ETA: 2s - loss: 0.1367 - acc: 0.956 - ETA: 2s - loss: 0.1377 - acc: 0.956 - ETA: 2s - loss: 0.1371 - acc: 0.956 - ETA: 2s - loss: 0.1328 - acc: 0.958 - ETA: 2s - loss: 0.1350 - acc: 0.957 - ETA: 2s - loss: 0.1323 - acc: 0.958 - ETA: 2s - loss: 0.1334 - acc: 0.958 - ETA: 2s - loss: 0.1365 - acc: 0.958 - ETA: 2s - loss: 0.1384 - acc: 0.956 - ETA: 2s - loss: 0.1365 - acc: 0.956 - ETA: 2s - loss: 0.1333 - acc: 0.957 - ETA: 2s - loss: 0.1326 - acc: 0.957 - ETA: 2s - loss: 0.1332 - acc: 0.957 - ETA: 2s - loss: 0.1319 - acc: 0.957 - ETA: 2s - loss: 0.1322 - acc: 0.957 - ETA: 1s - loss: 0.1336 - acc: 0.956 - ETA: 1s - loss: 0.1338 - acc: 0.956 - ETA: 1s - loss: 0.1342 - acc: 0.956 - ETA: 1s - loss: 0.1338 - acc: 0.956 - ETA: 1s - loss: 0.1325 - acc: 0.956 - ETA: 1s - loss: 0.1314 - acc: 0.957 - ETA: 1s - loss: 0.1319 - acc: 0.957 - ETA: 1s - loss: 0.1315 - acc: 0.957 - ETA: 1s - loss: 0.1297 - acc: 0.957 - ETA: 1s - loss: 0.1287 - acc: 0.957 - ETA: 1s - loss: 0.1276 - acc: 0.958 - ETA: 1s - loss: 0.1257 - acc: 0.958 - ETA: 1s - loss: 0.1263 - acc: 0.958 - ETA: 1s - loss: 0.1274 - acc: 0.958 - ETA: 1s - loss: 0.1359 - acc: 0.956 - ETA: 1s - loss: 0.1359 - acc: 0.955 - ETA: 0s - loss: 0.1357 - acc: 0.956 - ETA: 0s - loss: 0.1358 - acc: 0.956 - ETA: 0s - loss: 0.1379 - acc: 0.955 - ETA: 0s - loss: 0.1372 - acc: 0.955 - ETA: 0s - loss: 0.1370 - acc: 0.955 - ETA: 0s - loss: 0.1373 - acc: 0.955 - ETA: 0s - loss: 0.1362 - acc: 0.955 - ETA: 0s - loss: 0.1355 - acc: 0.955 - ETA: 0s - loss: 0.1359 - acc: 0.955 - ETA: 0s - loss: 0.1375 - acc: 0.954 - ETA: 0s - loss: 0.1398 - acc: 0.954 - ETA: 0s - loss: 0.1396 - acc: 0.954 - ETA: 0s - loss: 0.1418 - acc: 0.954 - ETA: 0s - loss: 0.1419 - acc: 0.954 - ETA: 0s - loss: 0.1420 - acc: 0.954 - ETA: 0s - loss: 0.1416 - acc: 0.954 - ETA: 0s - loss: 0.1411 - acc: 0.954 - ETA: 0s - loss: 0.1411 - acc: 0.9544Epoch 00016: val_loss did not improve
# 6680/6680 [==============================] - 4s - loss: 0.1408 - acc: 0.9545 - val_loss: 2.9922 - val_acc: 0.5593
# Epoch 18/20
# 6660/6680 [============================>.] - ETA: 4s - loss: 0.1415 - acc: 0.950 - ETA: 3s - loss: 0.2164 - acc: 0.933 - ETA: 3s - loss: 0.1701 - acc: 0.954 - ETA: 3s - loss: 0.1393 - acc: 0.962 - ETA: 3s - loss: 0.1389 - acc: 0.952 - ETA: 3s - loss: 0.1398 - acc: 0.951 - ETA: 3s - loss: 0.1370 - acc: 0.951 - ETA: 3s - loss: 0.1260 - acc: 0.955 - ETA: 3s - loss: 0.1211 - acc: 0.958 - ETA: 3s - loss: 0.1138 - acc: 0.962 - ETA: 3s - loss: 0.1260 - acc: 0.964 - ETA: 3s - loss: 0.1316 - acc: 0.964 - ETA: 3s - loss: 0.1254 - acc: 0.965 - ETA: 3s - loss: 0.1265 - acc: 0.964 - ETA: 3s - loss: 0.1315 - acc: 0.962 - ETA: 3s - loss: 0.1271 - acc: 0.963 - ETA: 2s - loss: 0.1247 - acc: 0.963 - ETA: 2s - loss: 0.1255 - acc: 0.962 - ETA: 2s - loss: 0.1198 - acc: 0.964 - ETA: 2s - loss: 0.1164 - acc: 0.964 - ETA: 2s - loss: 0.1182 - acc: 0.964 - ETA: 2s - loss: 0.1148 - acc: 0.965 - ETA: 2s - loss: 0.1160 - acc: 0.965 - ETA: 2s - loss: 0.1162 - acc: 0.964 - ETA: 2s - loss: 0.1129 - acc: 0.966 - ETA: 2s - loss: 0.1108 - acc: 0.965 - ETA: 2s - loss: 0.1107 - acc: 0.965 - ETA: 2s - loss: 0.1115 - acc: 0.965 - ETA: 2s - loss: 0.1165 - acc: 0.964 - ETA: 2s - loss: 0.1138 - acc: 0.965 - ETA: 2s - loss: 0.1166 - acc: 0.964 - ETA: 2s - loss: 0.1149 - acc: 0.965 - ETA: 2s - loss: 0.1219 - acc: 0.962 - ETA: 1s - loss: 0.1246 - acc: 0.960 - ETA: 1s - loss: 0.1270 - acc: 0.960 - ETA: 1s - loss: 0.1261 - acc: 0.960 - ETA: 1s - loss: 0.1250 - acc: 0.960 - ETA: 1s - loss: 0.1255 - acc: 0.959 - ETA: 1s - loss: 0.1265 - acc: 0.959 - ETA: 1s - loss: 0.1258 - acc: 0.960 - ETA: 1s - loss: 0.1266 - acc: 0.959 - ETA: 1s - loss: 0.1256 - acc: 0.960 - ETA: 1s - loss: 0.1248 - acc: 0.960 - ETA: 1s - loss: 0.1235 - acc: 0.961 - ETA: 1s - loss: 0.1234 - acc: 0.961 - ETA: 1s - loss: 0.1249 - acc: 0.960 - ETA: 1s - loss: 0.1272 - acc: 0.960 - ETA: 1s - loss: 0.1274 - acc: 0.959 - ETA: 1s - loss: 0.1291 - acc: 0.958 - ETA: 1s - loss: 0.1286 - acc: 0.958 - ETA: 1s - loss: 0.1276 - acc: 0.958 - ETA: 1s - loss: 0.1289 - acc: 0.957 - ETA: 0s - loss: 0.1303 - acc: 0.957 - ETA: 0s - loss: 0.1304 - acc: 0.957 - ETA: 0s - loss: 0.1301 - acc: 0.956 - ETA: 0s - loss: 0.1308 - acc: 0.956 - ETA: 0s - loss: 0.1318 - acc: 0.956 - ETA: 0s - loss: 0.1336 - acc: 0.955 - ETA: 0s - loss: 0.1343 - acc: 0.955 - ETA: 0s - loss: 0.1338 - acc: 0.955 - ETA: 0s - loss: 0.1333 - acc: 0.956 - ETA: 0s - loss: 0.1333 - acc: 0.956 - ETA: 0s - loss: 0.1346 - acc: 0.956 - ETA: 0s - loss: 0.1348 - acc: 0.956 - ETA: 0s - loss: 0.1371 - acc: 0.955 - ETA: 0s - loss: 0.1365 - acc: 0.955 - ETA: 0s - loss: 0.1364 - acc: 0.955 - ETA: 0s - loss: 0.1381 - acc: 0.954 - ETA: 0s - loss: 0.1381 - acc: 0.955 - ETA: 0s - loss: 0.1381 - acc: 0.954 - ETA: 0s - loss: 0.1371 - acc: 0.9554Epoch 00017: val_loss did not improve
# 6680/6680 [==============================] - 4s - loss: 0.1372 - acc: 0.9552 - val_loss: 3.0753 - val_acc: 0.5461
# Epoch 19/20
# 6640/6680 [============================>.] - ETA: 4s - loss: 0.0459 - acc: 1.000 - ETA: 3s - loss: 0.0852 - acc: 0.975 - ETA: 3s - loss: 0.1417 - acc: 0.945 - ETA: 3s - loss: 0.1061 - acc: 0.962 - ETA: 3s - loss: 0.0942 - acc: 0.966 - ETA: 3s - loss: 0.1032 - acc: 0.963 - ETA: 3s - loss: 0.0953 - acc: 0.966 - ETA: 3s - loss: 0.0892 - acc: 0.968 - ETA: 3s - loss: 0.0890 - acc: 0.967 - ETA: 3s - loss: 0.0822 - acc: 0.970 - ETA: 3s - loss: 0.0783 - acc: 0.972 - ETA: 3s - loss: 0.0769 - acc: 0.972 - ETA: 3s - loss: 0.0809 - acc: 0.970 - ETA: 3s - loss: 0.0822 - acc: 0.968 - ETA: 3s - loss: 0.0796 - acc: 0.969 - ETA: 3s - loss: 0.0826 - acc: 0.968 - ETA: 3s - loss: 0.0822 - acc: 0.968 - ETA: 3s - loss: 0.0830 - acc: 0.968 - ETA: 2s - loss: 0.0827 - acc: 0.968 - ETA: 2s - loss: 0.0797 - acc: 0.969 - ETA: 2s - loss: 0.0873 - acc: 0.967 - ETA: 2s - loss: 0.0907 - acc: 0.966 - ETA: 2s - loss: 0.0907 - acc: 0.966 - ETA: 2s - loss: 0.0927 - acc: 0.965 - ETA: 2s - loss: 0.0945 - acc: 0.964 - ETA: 2s - loss: 0.0934 - acc: 0.965 - ETA: 2s - loss: 0.0919 - acc: 0.966 - ETA: 2s - loss: 0.0903 - acc: 0.966 - ETA: 2s - loss: 0.0905 - acc: 0.967 - ETA: 2s - loss: 0.0895 - acc: 0.967 - ETA: 2s - loss: 0.0928 - acc: 0.965 - ETA: 2s - loss: 0.0935 - acc: 0.965 - ETA: 2s - loss: 0.0923 - acc: 0.965 - ETA: 2s - loss: 0.0911 - acc: 0.966 - ETA: 2s - loss: 0.0920 - acc: 0.965 - ETA: 1s - loss: 0.0914 - acc: 0.965 - ETA: 1s - loss: 0.0904 - acc: 0.966 - ETA: 1s - loss: 0.0915 - acc: 0.966 - ETA: 1s - loss: 0.0918 - acc: 0.965 - ETA: 1s - loss: 0.0911 - acc: 0.966 - ETA: 1s - loss: 0.0908 - acc: 0.966 - ETA: 1s - loss: 0.0892 - acc: 0.967 - ETA: 1s - loss: 0.0917 - acc: 0.966 - ETA: 1s - loss: 0.0949 - acc: 0.965 - ETA: 1s - loss: 0.0973 - acc: 0.964 - ETA: 1s - loss: 0.0989 - acc: 0.964 - ETA: 1s - loss: 0.0983 - acc: 0.964 - ETA: 1s - loss: 0.0982 - acc: 0.963 - ETA: 1s - loss: 0.0987 - acc: 0.964 - ETA: 1s - loss: 0.1004 - acc: 0.963 - ETA: 1s - loss: 0.0999 - acc: 0.964 - ETA: 1s - loss: 0.1052 - acc: 0.963 - ETA: 0s - loss: 0.1052 - acc: 0.963 - ETA: 0s - loss: 0.1048 - acc: 0.963 - ETA: 0s - loss: 0.1053 - acc: 0.963 - ETA: 0s - loss: 0.1067 - acc: 0.962 - ETA: 0s - loss: 0.1095 - acc: 0.962 - ETA: 0s - loss: 0.1089 - acc: 0.962 - ETA: 0s - loss: 0.1127 - acc: 0.961 - ETA: 0s - loss: 0.1134 - acc: 0.961 - ETA: 0s - loss: 0.1142 - acc: 0.961 - ETA: 0s - loss: 0.1137 - acc: 0.961 - ETA: 0s - loss: 0.1136 - acc: 0.961 - ETA: 0s - loss: 0.1138 - acc: 0.961 - ETA: 0s - loss: 0.1138 - acc: 0.961 - ETA: 0s - loss: 0.1127 - acc: 0.962 - ETA: 0s - loss: 0.1158 - acc: 0.961 - ETA: 0s - loss: 0.1161 - acc: 0.961 - ETA: 0s - loss: 0.1170 - acc: 0.9605Epoch 00018: val_loss did not improve
# 6680/6680 [==============================] - 4s - loss: 0.1172 - acc: 0.9606 - val_loss: 2.9885 - val_acc: 0.5749
# Epoch 20/20
# 6620/6680 [============================>.] - ETA: 4s - loss: 0.0620 - acc: 1.000 - ETA: 3s - loss: 0.2096 - acc: 0.950 - ETA: 3s - loss: 0.1334 - acc: 0.963 - ETA: 3s - loss: 0.1225 - acc: 0.968 - ETA: 3s - loss: 0.1041 - acc: 0.973 - ETA: 3s - loss: 0.0916 - acc: 0.978 - ETA: 3s - loss: 0.0784 - acc: 0.981 - ETA: 3s - loss: 0.0698 - acc: 0.984 - ETA: 3s - loss: 0.0692 - acc: 0.984 - ETA: 3s - loss: 0.0649 - acc: 0.986 - ETA: 3s - loss: 0.0629 - acc: 0.986 - ETA: 3s - loss: 0.0602 - acc: 0.986 - ETA: 3s - loss: 0.0707 - acc: 0.983 - ETA: 3s - loss: 0.0783 - acc: 0.980 - ETA: 3s - loss: 0.0845 - acc: 0.976 - ETA: 3s - loss: 0.0853 - acc: 0.975 - ETA: 2s - loss: 0.0821 - acc: 0.977 - ETA: 2s - loss: 0.0821 - acc: 0.977 - ETA: 2s - loss: 0.0816 - acc: 0.978 - ETA: 2s - loss: 0.0844 - acc: 0.976 - ETA: 2s - loss: 0.0833 - acc: 0.976 - ETA: 2s - loss: 0.0819 - acc: 0.976 - ETA: 2s - loss: 0.0845 - acc: 0.975 - ETA: 2s - loss: 0.0860 - acc: 0.974 - ETA: 2s - loss: 0.0940 - acc: 0.973 - ETA: 2s - loss: 0.0926 - acc: 0.974 - ETA: 2s - loss: 0.0923 - acc: 0.974 - ETA: 2s - loss: 0.0903 - acc: 0.975 - ETA: 2s - loss: 0.0938 - acc: 0.973 - ETA: 2s - loss: 0.0958 - acc: 0.973 - ETA: 2s - loss: 0.0973 - acc: 0.972 - ETA: 2s - loss: 0.0979 - acc: 0.973 - ETA: 2s - loss: 0.0969 - acc: 0.973 - ETA: 1s - loss: 0.0961 - acc: 0.973 - ETA: 1s - loss: 0.0969 - acc: 0.973 - ETA: 1s - loss: 0.0975 - acc: 0.972 - ETA: 1s - loss: 0.0973 - acc: 0.972 - ETA: 1s - loss: 0.0987 - acc: 0.971 - ETA: 1s - loss: 0.0982 - acc: 0.971 - ETA: 1s - loss: 0.0976 - acc: 0.971 - ETA: 1s - loss: 0.1008 - acc: 0.970 - ETA: 1s - loss: 0.1027 - acc: 0.969 - ETA: 1s - loss: 0.1028 - acc: 0.970 - ETA: 1s - loss: 0.1011 - acc: 0.970 - ETA: 1s - loss: 0.0996 - acc: 0.971 - ETA: 1s - loss: 0.0997 - acc: 0.971 - ETA: 1s - loss: 0.0997 - acc: 0.970 - ETA: 1s - loss: 0.0985 - acc: 0.970 - ETA: 1s - loss: 0.0990 - acc: 0.970 - ETA: 1s - loss: 0.1004 - acc: 0.969 - ETA: 1s - loss: 0.0997 - acc: 0.969 - ETA: 0s - loss: 0.0993 - acc: 0.969 - ETA: 0s - loss: 0.0991 - acc: 0.969 - ETA: 0s - loss: 0.0977 - acc: 0.969 - ETA: 0s - loss: 0.0983 - acc: 0.969 - ETA: 0s - loss: 0.1008 - acc: 0.968 - ETA: 0s - loss: 0.1013 - acc: 0.968 - ETA: 0s - loss: 0.1009 - acc: 0.968 - ETA: 0s - loss: 0.1012 - acc: 0.968 - ETA: 0s - loss: 0.1011 - acc: 0.968 - ETA: 0s - loss: 0.1021 - acc: 0.968 - ETA: 0s - loss: 0.1015 - acc: 0.968 - ETA: 0s - loss: 0.1024 - acc: 0.968 - ETA: 0s - loss: 0.1052 - acc: 0.968 - ETA: 0s - loss: 0.1064 - acc: 0.967 - ETA: 0s - loss: 0.1057 - acc: 0.967 - ETA: 0s - loss: 0.1065 - acc: 0.967 - ETA: 0s - loss: 0.1071 - acc: 0.9669Epoch 00019: val_loss did not improve
# 6680/6680 [==============================] - 4s - loss: 0.1083 - acc: 0.9666 - val_loss: 3.0990 - val_acc: 0.5713

# %% [markdown]
# ### (IMPLEMENTATION) Load the Model with the Best Validation Loss

# %%
### TODO: Load the model weights with the best validation loss.
model1.load_weights('saved_models/weights.best.VGG16_from_scratch.hdf5')

# %% [markdown]
# ### (IMPLEMENTATION) Test the Model
#
# Try out your model on the test dataset of dog images. Ensure that your test accuracy is greater than 60%.

# %%
### TODO: Calculate classification accuracy on the test dataset.
# get index of predicted dog breed for each image in test set
VGG16_predictions = [np.argmax(model1.predict(np.expand_dims(feature, axis=0))) for feature in test_VGG16]

# report test accuracy
test_accuracy = 100*np.sum(np.array(VGG16_predictions)==np.argmax(test_targets, axis=1))/len(VGG16_predictions)
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 56.2201%

# %% [markdown]
# ### (IMPLEMENTATION) Predict Dog Breed with the Model
#
# Write a function that takes an image path as input and returns the dog breed (`Affenpinscher`, `Afghan_hound`, etc) that is predicted by your model.
#
# Similar to the analogous function in Step 5, your function should have three steps:
# 1. Extract the bottleneck features corresponding to the chosen CNN model.
# 2. Supply the bottleneck features as input to the model to return the predicted vector.  Note that the argmax of this prediction vector gives the index of the predicted dog breed.
# 3. Use the `dog_names` array defined in Step 0 of this notebook to return the corresponding breed.
#
# The functions to extract the bottleneck features can be found in `extract_bottleneck_features.py`, and they have been imported in an earlier code cell.  To obtain the bottleneck features corresponding to your chosen CNN architecture, you need to use the function
#
#     extract_{network}
#
# where `{network}`, in the above filename, should be one of `VGG19`, `Resnet50`, `InceptionV3`, or `Xception`.

# %%
### TODO: Write a function that takes a path to an image as input
### and returns the dog breed that is predicted by the model.
from extract_bottleneck_features import *

def My_predict_breed(img_path):
    # extract bottleneck features
    bottleneck_feature = extract_VGG16(path_to_tensor(img_path))
    # obtain predicted vector
    predicted_vector = model1.predict(bottleneck_feature)
    # return dog breed that is predicted by the model
    return dog_names[np.argmax(predicted_vector)]

# %% [markdown]
# ---
# <a id='step6'></a>
# ## Step 6: Write your Algorithm
#
# Write an algorithm that accepts a file path to an image and first determines whether the image contains a human, dog, or neither.  Then,
# - if a __dog__ is detected in the image, return the predicted breed.
# - if a __human__ is detected in the image, return the resembling dog breed.
# - if __neither__ is detected in the image, provide output that indicates an error.
#
# You are welcome to write your own functions for detecting humans and dogs in images, but feel free to use the `face_detector` and `dog_detector` functions developed above.  You are __required__ to use your CNN from Step 5 to predict dog breed.
#
# Some sample output for our algorithm is provided below, but feel free to design your own user experience!
#
# ![Sample Human Output](images/sample_human_output.png)
#
#
# ### (IMPLEMENTATION) Write your Algorithm

# %%
### TODO: Write your algorithm.
### Feel free to use as many code cells as needed.
def predactor(image_path):
    if dog_detector(image_path):
        print("this is "+str(My_predict_breed(img_path)))
    elif face_detector(img_path):
        print("You look like a ..."+ str(My_predict_breed(img_path)))
    else:
        print("It is hard to recognize this.")

# %% [markdown]
# ---
# <a id='step7'></a>
# ## Step 7: Test Your Algorithm
#
# In this section, you will take your new algorithm for a spin!  What kind of dog does the algorithm think that __you__ look like?  If you have a dog, does it predict your dog's breed accurately?  If you have a cat, does it mistakenly think that your cat is a dog?
#
# ### (IMPLEMENTATION) Test Your Algorithm on Sample Images!
#
# Test your algorithm at least six images on your computer.  Feel free to use any images you like.  Use at least two human and two dog images.
#
# __Question 6:__ Is the output better than you expected :) ?  Or worse :( ?  Provide at least three possible points of improvement for your algorithm.
#
# __Answer:__

# %%
def show_image(img_path):
    img = cv2.imread(img_path)
    cv_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.imshow(cv_rgb)
    plt.show()

# %%
## TODO: Execute your algorithm from Step 6 on
## at least 6 images on your computer.
## Feel free to use as many code cells as needed.
def load_test_dataset():
    data = load_files('C:/Users/Zaher/Documents/GitHub/cnn-project/dog-project/dogImages/testDataSet')
    dog_files = np.array(data['filenames'])
    return dog_files
for img_path in load_test_dataset():
    show_image(img_path)
    predactor(img_path)
# Out:
# You look like a ...Dachshund
# this is Basset_hound
# this is Brittany
# this is Cane_corso
# this is Irish_red_and_white_setter
# this is Kerry_blue_terrier
# this is Afghan_hound
# this is Labrador_retriever
# this is Curly-coated_retriever
# this is Black_and_tan_coonhound
# this is Labrador_retriever
# You look like a ...Canaan_dog
# You look like a ...Cane_corso
# You look like a ...Dachshund
# this is Chesapeake_bay_retriever
